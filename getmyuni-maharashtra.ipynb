# %%
import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd
#import pandas inorder to create dataframes

# %%
url="https://www.getmyuni.com/all-colleges/maharashtra"

# %%
r=requests.get("https://www.getmyuni.com/all-colleges/maharashtra")

# %%
soup=BeautifulSoup(r.content,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <!-- <meta http-equiv="Content-Type" content="text/html"> -->
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=0" name="viewport">
# <meta content="#545ebd" name="theme-color"/>
# <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
# <!-- <link rel="dns-prefetch" href="//cdnjs.cloudflare.com/"> -->
# <link crossorigin="" href="https://www.googletagmanager.com/" rel="preconnect"/>
# <link href="//www.google-analytics.com" rel="preconnect">
# <!-- <link rel="preconnect" href="https://cdnjs.cloudflare.com/" /> -->
# <link href="https://securepubads.g.doubleclick.net" rel="preconnect"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch">
# <link href="https://securepubads.g.doubleclick.net" rel="dns-prefetch"/>
# <!-- <link rel="dns-prefetch" crossorigin href="https://fonts.googleapis.com/" /> -->
# ...

# %%
names=soup.find_all('h2',class_='college__name')
city=soup.find_all('div',class_='detail__list__mobile')
fees=soup.find_all('span',class_='highlight__value')

# %%
college_names = []
college_cities = []
college_fees = []

# %%
for name, city, fee in zip(names, city, fees):
    college_names.append(name.text.strip())
    college_cities.append(city.text.strip())
    college_fees.append(fee.text.strip())

# %%
college_data = {'college_names':college_names, 'college_cities':college_cities, 'college_fees':college_fees}
print(college_data)
# Out:
# {'college_names': ['IIT Bombay', 'UniPune (SPPU)', 'IISER Pune', 'ICT Mumbai', 'MIT-WPU', 'Lotus Business School', 'Homi Bhabha National Institute, [HBNI] Mumbai', 'VNIT Nagpur', 'SIU Pune', 'TISS Mumbai', 'Vignan Online', 'Dr. D.Y. Patil Vidyapeeth, Pune', 'NMIMS Mumbai', 'Mumbai University', 'Datta Meghe Institute of Medical Sciences', 'SIMC Pune', 'JBIMS Mumbai', 'Welingkar Mumbai', 'K J Somaiya Institute of Management', 'SIMSREE-Sydenham', 'SIDTM', 'Pune Institute of Business Management', 'NL Dalmia Institute', 'NITIE Mumbai', 'VIT Pune', 'SIIB Pune', 'Kishinchand Chellaram College', 'MIT-WPU', 'Pimpri Chinchwad College of Engineering', 'SCMHRD Pune'], 'college_cities': ['Mumbai, Maharashtra\nPublic\n4.3 \n # 3 NIRF', 'Pune, Maharashtra\nPublic\n3.3 \n # 37 NIRF', 'Pune, Maharashtra\nPublic\n4.0 \n # 42 NIRF', 'Mumbai, Maharashtra\nPublic\n3.8 \n # 56 NIRF', 'Pune, Maharashtra\nPrivate\n3.7', 'Pune, Maharashtra\nPrivate\n4.2', 'Mumbai, Maharashtra\nPublic\n # 27 NIRF', 'Nagpur, M
# ...

# %%
#converting dictionary into a dataframe
model=pd.DataFrame(college_data)
model.to_csv("colleges_maharashtra_data.csv")
model
# Out:
#                                     college_names  \
# 0                                      IIT Bombay
# 1                                  UniPune (SPPU)
# 2                                      IISER Pune
# 3                                      ICT Mumbai
# 4                                         MIT-WPU
# 5                           Lotus Business School
# 6   Homi Bhabha National Institute, [HBNI] Mumbai
# 7                                     VNIT Nagpur
# 8                                        SIU Pune
# 9                                     TISS Mumbai
# 10                                  Vignan Online
# 11                Dr. D.Y. Patil Vidyapeeth, Pune
# 12                                   NMIMS Mumbai
# 13                              Mumbai University
# 14      Datta Meghe Institute of Medical Sciences
# 15                                      SIMC Pune
# 16                                   JBIMS Mumbai
# 17                               Welingkar Mumbai
# ...
