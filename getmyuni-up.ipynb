# %%
import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd
#import pandas inorder to create dataframes

# %%
url="https://www.getmyuni.com/all-colleges/uttar-pradesh"

# %%
r=requests.get("https://www.getmyuni.com/all-colleges/uttar-pradesh")

# %%
soup=BeautifulSoup(r.content,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <!-- <meta http-equiv="Content-Type" content="text/html"> -->
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=0" name="viewport">
# <meta content="#545ebd" name="theme-color"/>
# <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
# <!-- <link rel="dns-prefetch" href="//cdnjs.cloudflare.com/"> -->
# <link crossorigin="" href="https://www.googletagmanager.com/" rel="preconnect"/>
# <link href="//www.google-analytics.com" rel="preconnect">
# <!-- <link rel="preconnect" href="https://cdnjs.cloudflare.com/" /> -->
# <link href="https://securepubads.g.doubleclick.net" rel="preconnect"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch">
# <link href="https://securepubads.g.doubleclick.net" rel="dns-prefetch"/>
# <!-- <link rel="dns-prefetch" crossorigin href="https://fonts.googleapis.com/" /> -->
# <link href="https://www.getmyuni.com/favicon.png" rel="shortcut icon" type="image/png">
# <link href="https://www.getmyuni.com/favicon.png" rel="icon" type="image/x-icon"/>
# <link as="font" crossorigin="" href="/yas/fonts/woff/roboto-regular-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/yas/fonts/woff/roboto-medium-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/yas/fonts/woff/roboto-bold-webfont.woff2" rel="preload" type="font/woff2"/>
# <link href="/yas/css/version2/jquery-ui.min.css" media="print" onload="this.media='all'" rel="stylesheet"/>
# <title>
#         Top Colleges in Uttar Pradesh 2024: Ranking, Courses, Fees &amp; Placements    </title>
# <meta content="Find Top Colleges in Uttar Pradesh based on  ranking with details on courses, fees, placements, admission, reviews, cut off, and latest news." name="description"/>
# <meta content="website" property="og:type"/>
# <meta content="Top Colleges in Uttar Pradesh 2024: Ranking, Courses, Fees &amp; Placements" property="og:title"/>
# <meta content="https://www.getmyuni.com/all-colleges/uttar-pradesh" property="og:url"/>
# <meta content="Getmyuni" property="og:site_name"/>
# <meta content="Find Top Colleges in Uttar Pradesh based on  ranking with details on courses, fees, placements, admission, reviews, cut off, and latest news." property="og:description"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Getmyuni" property="twitter:site"/>
# <meta content="@getmyuniedu" property="twitter:creator"/>
# <meta content="https://www.getmyuni.com/all-colleges/uttar-pradesh" property="twitter:url"/>
# <meta content="Top Colleges in Uttar Pradesh 2024: Ranking, Courses, Fees &amp; Placements" property="twitter:title"/>
# <meta content="Find Top Colleges in Uttar Pradesh based on  ranking with details on courses, fees, placements, admission, reviews, cut off, and latest news." property="twitter:description"/>
# <meta content="https://media.getmyuni.com/yas/images/banner.png" property="og:image"/>
# <meta content="https://media.getmyuni.com/yas/images/banner.png" property="twitter:image"/>
# <link href="https://www.getmyuni.com/all-colleges/uttar-pradesh" rel="canonical"/>
# <link href="/yas/css/version2/min/style.css?v=1729774232" rel="stylesheet"/>
# <link href="/yas/css/version2/min/header.css?v=1729774232" rel="stylesheet"/>
# <link href="/yas/css/version2/college-landing-new.css?v=1729071435" rel="stylesheet"/>
# <link href="/yas/css/version2/college-compare-panel.css?v=1729071435" rel="stylesheet"/>
# <style>.blueBgDiv.mobileOnly { display: none!important; }</style> <script>
#         var gmu = {};
#         gmu.config = {
#             showLeadForm: 'true',
#             entity: 'college-listing',
#             product_mapping_entity: 'false',
#             product_mapping_entity_id: 0,
#             pageName: '',
#             entity_id: 0,
#             college_course_count: '',
#             course_id: '',
#             program_id: '',
#             entity_name: "College-Listing-Page",
#             entity_slug: '',
#             board_level: '',
#             display_name: '',
#             pageName: '',
#             page_category: '',
#             entity_type: 'college-listing',
#             entity_subtype: 'state',
#             entity_city: '',
#             interested_location: '',
#             interested_location_state: '',
#             cta_location: 'auto-popup',
#             show_lead_form: false,
#             utm_source: '',
#             utm_campaign: '',
#             utm_medium: '',
#             sponsor_params: {"state":"uttar-pradesh","stream":null,"course":null,"specialization":null},
#             courseChartData: [],
#             isLoggedIn: false,
#             previous_url: '',
#             page_url: 'https://www.getmyuni.com/all-colleges/uttar-pradesh',
#             isMobile: '',
#             mapData: [],
#             statusCode: 200,
#             currentLocation: 'https://www.getmyuni.com/all-colleges/uttar-pradesh',
#             dynamicCta: {"cta_position_0":{"lead_form_title":"Sign-up to Download","lead_form_description":", ","cta_text":"<span class=\"spriteIcon whiteDownloadIcon redDownloadIcon\"><\/span> Brochure","cta_title":"","page_event":null,"page_link":null,"web":"colleges_listing__card_left_cta_web","wap":"colleges_listing__card_left_cta_wap","template":2},"cta_position_1":{"lead_form_title":"Sign-up to Apply","lead_form_description":", ","cta_text":"Apply Now","cta_title":"","page_event":null,"page_link":null,"web":"colleges_listing__card_right_cta_web","wap":"colleges_listing__card_right_cta_wap","template":2},"cta_position_2":{"lead_form_title":"Sign-up to Download","lead_form_description":", ","cta_text":"<span class=\"spriteIcon whiteDownloadIcon redDownloadIcon\"><\/span> Brochure","cta_title":"","page_event":null,"page_link":null,"web":"colleges_listing__card_left_cta1_web","wap":"colleges_listing__card_left_cta1_wap","template":2},"cta_position_3":{"lead_form_title":"Register to Shortlist","lead_form_description":"Register to Shortlist","cta_text":"Shortlist","cta_title":"","page_event":null,"page_link":null,"web":"colleges_listing__card_right_cta1_web","wap":"colleges_listing__card_right_cta1_wap","template":2},"cta_position_4":{"lead_form_title":"Get Counselling from experts, free of cost !","lead_form_description":"","cta_text":"Talk to Experts","cta_title":"","page_event":null,"page_link":null,"web":"colleges_listing_single_top_cta_web","wap":"colleges_listing_single_top_cta_wap","template":2}},
#             csrf: 'YPZ_nSjof6dAy253-YTeFkFOl4ToGjo55xM1Rlxtd2dRoDnER9g0zSuPPya0srFSKwO664dqcWCqSkwEFyUUNQ==',
#             language: 'en',
#             domainUrl: 'https://www.getmyuni.com/',
#             prodEvn : 'prod',
#             careerChartData: [],
#         };
#
#         var googletag = googletag || {};
#         googletag.cmd = googletag.cmd || [];
#         // GPT slots
#         var gptAdSlots = [];
#         googletag.cmd.push(function() {
#             gptAdSlots[0] = googletag.defineSlot('/21840540389/gmu_new_listing_page_web_390x90_mtf_1', [390,90], 'div-gpt-ad-1614408539431-0').addService(googletag.pubads());
# gptAdSlots[1] = googletag.defineSlot('/21840540389/gmu_new_listing_page_web_390x90_mtf_1', [390,90], 'div-gpt-ad-1614408539431-1').addService(googletag.pubads());
# gptAdSlots[2] = googletag.defineSlot('/21840540389/gmu_new_listing_page_web_390x90_mtf_1', [390,90], 'div-gpt-ad-1614408539431-2').addService(googletag.pubads());
# gptAdSlots[3] = googletag.defineSlot('/21840540389/gmu_new_listing_page_web_250x200_mtf_1', [250,200], 'div-gpt-ad-1614408539431-3').addService(googletag.pubads());
# gptAdSlots[4] = googletag.defineSlot('/21840540389/gmu_new_listing_page_web_250x200_mtf_1', [250,200], 'div-gpt-ad-1614408539431-4').addService(googletag.pubads());
# gptAdSlots[5] = googletag.defineSlot('/21840540389/gmu_new_listing_page_web_390x90_mtf_1', [390,90], 'div-gpt-ad-1614408539431-5').addService(googletag.pubads());
#
#             // Configure SRA
#             googletag.pubads().enableSingleRequest();
#             googletag.pubads().enableLazyLoad();
#             // Start ad fetching
#             googletag.enableServices();
#         });
#     </script>
# <script id="_webengage_script_tag" type="text/javascript">
#         var webengage;
#         ! function(w, e, b, n, g) {
#             function o(e, t) {
#                 e[t[t.length - 1]] = function() {
#                     r.__queue.push([t.join("."), arguments])
#                 }
#             }
#             var i, s, r = w[b],
#                 z = " ",
#                 l = "init options track screen onReady".split(z),
#                 a = "feedback survey notification".split(z),
#                 c = "options render clear abort".split(z),
#                 p = "Open Close Submit Complete View Click".split(z),
#                 u = "identify login logout setAttribute".split(z);
#             if (!r || !r.__v) {
#                 for (w[b] = r = {
#                         __queue: [],
#                         __v: "6.0",
#                         user: {}
#                     }, i = 0; i < l.length; i++) o(r, [l[i]]);
#                 for (i = 0; i < a.length; i++) {
#                     for (r[a[i]] = {}, s = 0; s < c.length; s++) o(r[a[i]], [a[i], c[s]]);
#                     for (s = 0; s < p.length; s++) o(r[a[i]], [a[i], "on" + p[s]])
#                 }
#                 for (i = 0; i < u.length; i++) o(r.user, ["user", u[i]]);
#                 setTimeout(function() {
#                     var f = e.createElement("script"),
#                         d = e.getElementById("_webengage_script_tag");
#                     f.type = "text/javascript",
#                         f.async = !0,
#                         f.src = ("https:" == e.location.protocol ? "https://widgets.in.webengage.com" : "http://widgets.in.webengage.com") + "/js/webengage-min-v-6.0.js",
#                         d.parentNode.insertBefore(f, d);
#                 }, 10000)
#             }
#         }(window, document, "webengage");
#         webengage.init('in~d3a49c51');
#         webengage.onReady(function() {
#             webengage.notification.onOpen(function(data) {
#                 var a = document.getElementById('webklipper-publisher-widget-container-notification-frame');
#                 var layoutId = a.dataset.notificationLayoutId;
#                 if (layoutId == '~483819h') {
#                     a.style.left = 'auto';
#                     a.style.top = 'auto';
#                     a.style.transform = 'none';
#                     a.style.zIndex = 1;
#                     var _stickyBtn = document.getElementsByClassName("getSupport").length ? document.getElementsByClassName("getSupport")[0] : null;
#                     a.style.bottom = '0px';
#                     if (_stickyBtn) {
#                         a.style.bottom = _stickyBtn.getBoundingClientRect().height + 'px';
#                     }
#                     var throttle = function(callback, delay) {
#                         var throttleTimeout = null;
#                         var storedEvent = null;
#
#                         var throttledEventHandler = function(event) {
#                             storedEvent = event;
#
#                             var shouldHandleEvent = !throttleTimeout;
#
#                             if (shouldHandleEvent) {
#                                 callback(storedEvent);
#
#                                 storedEvent = null;
#
#                                 throttleTimeout = setTimeout(function() {
#                                     throttleTimeout = null;
#
#                                     if (storedEvent) {
#                                         throttledEventHandler(storedEvent);
#                                     }
#                                 }, delay);
#                             }
#                         };
#
#                         return throttledEventHandler;
#                     };
#                     var scrollThrottle = throttle(function() {
#                         if (_stickyBtn) {
#                             a.style.bottom = _stickyBtn.getBoundingClientRect().height + 'px';
#                         }
#                     }, 1000);
#                     document.addEventListener("scroll", scrollThrottle);
#                 }
#             });
#         });
#     </script>
# <!-- Google Tag Manager --> <script data-cfasync="false">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.defer=true;j.src= 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f); })(window,document,'script','dataLayer','GTM-MMVP8S');</script> <!-- End Google Tag Manager -->
# </link></link></link></meta></head>
# <!-- <body> -->
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MMVP8S" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>
#         (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-MMVP8S');
#     </script>
# <header class="page-header" id="primary-js-nav">
# <div class="topHeader">
# <div class="container">
# <div class="row">
# <div class="mobileOnly">
# <p class="spriteIcon hambergerIcon"></p>
# </div>
# <a class="spriteIcon headerLogo" href="/" title="Getmyuni"></a>
# <ul>
# <li><a href="https://www.getmyuni.com/all-colleges" title="Top Colleges in India">Top Colleges</a></li>
# <li><a href="https://www.getmyuni.com/courses" title="Courses in India">Top Courses</a></li>
# <li><a href="https://www.getmyuni.com/exams" title="Entrance Exams in India">Entrance Exams</a></li>
# <li><a href="https://www.getmyuni.com/boards" title="Education Boards in India">Boards</a></li>
# <li><a href="https://www.getmyuni.com/college/admissions" title="College Admission in India">Admission 2024</a></li>
# <li><a href="https://news.getmyuni.com/" title="News">News</a></li>
# <!-- <li><a href="javascript:;">Study Abroad</a></li> -->
# <!-- <li class="sa_dropdown">
#                         <a class="" href="javascript:;">Study Abroad<span class="spriteIcon whiteCaretIcon"></span></a>
#                         <ul class="study-abroad-options study-abroad">
#                             <li><a href="https://www.getmyuni.com/canada" title="Study in Canada">Study in Canada</a></li>
#                             <li><a href="https://www.getmyuni.com/uk" title="Study in UK">Study in UK</a></li>
#                             <li><a href="https://www.getmyuni.com/usa" title="Study in USA">Study in USA</a></li>
#                             <li><a href="https://www.getmyuni.com/australia" title="Study in Australia">Study in Australia</a></li>
#                             <li><a href="https://www.getmyuni.com/germany" title="Study in Germany">Study in Germany</a></li>
#                             <li><a href="https://ieltsmaterial.com/" target="_blank">IELTS Material</a></li>
#                         </ul>
#                     </li> -->
# <li class="sa_dropdown">
# <a class="" href="javascript:;">More<span class="spriteIcon whiteCaretIcon"></span></a>
# <ul class="study-abroad-options study-abroad">
# <!-- <li class="srcSpanIcon"></li> -->
# <!-- <div class="row">
#                                     <div class="col-md-12"> -->
# <!-- <ul> -->
# <li><a href="https://www.getmyuni.com/articles" title="Articles">Articles</a></li>
# <!-- <li><a title="NCERT" href="https://www.getmyuni.com/ncert">NCERT</a></li> -->
# <!-- <li><a title="Compare Colleges" class="submenulist" href="https://www.getmyuni.com/college-compare">Compare Colleges</a> -->
# <li><a class="submenulist" href="https://www.getmyuni.com/scholarships" title="Scholarships">Scholarships</a></li>
# <!-- <li><a title="Olympiads" class="submenulist" href="https://www.getmyuni.com/olympiad">Olympiads</a></li> -->
# <!-- <li><a title="Sarkari Exam" class="submenulist" href="https://www.getmyuni.com/sarkari-exam/">Sarkari Exam</a></li> -->
# <!-- <li><a title="Visual Stories" class="submenulist" href="https://webstories.getmyuni.com/">Visual Stories</a></li> -->
# <!-- <li><a title="QnA" href="https://www.getmyuni.com/q-n-a">QnA</a></li> -->
# <li><a class="submenulist" href="https://www.getmyuni.com/college-compare" title="College Compare">College Compare</a></li>
# <!-- </ul> -->
# <!-- </div>
#                                 </div> -->
# </ul>
# </li>
# <!-- <li><a href="https://www.getmyuni.com/college/reviews" title="College Reviews">Reviews</a></li> -->
# <li><a class="spriteIcon searchIcon" href="javascript:;"></a></li>
# <li><a class="writeReview" href="https://www.getmyuni.com/review/create" title="Write a Review">Write a review</a></li>
# <!-- <a class="registerNew" id="mobileRegisterNew" href="/site/login">Login/ Register</a> -->
# <li id="registerNew"><a class="writeReview" href="/site/login">Login/ Register</a></li>
# <li id="loggedInUser"></li>
# <!-- <li><a class="register" href="https://www.getmyuni.com/login" title="Login / Register">Login / Register</a></li> -->
# </ul>
# <div class="mobileOnly">
# <a class="spriteIcon searchIcon"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="headerMegaMenu" id="secondaryHeader-web"></div>
# <div class="advanceSearch">
# <div class="searchWrap active">
# <a class="close-layer desktopOnly"></a>
# <div class="searchContent">
# <div class="seachInner">
# <div class="sugstrbox">
# <div class="inputDiv">
# <span class="mobileOnly leftArrow">
# <i class="spriteIcon backIcon"></i>
# </span>
# <input autocomplete="off" class="form-control seachInput" id="seachInput" placeholder="Search Colleges, Courses, Exams" tabindex="1" type="text" value=""/>
# <div class="close-icone inputClose">
# <span class="close-span"></span>
# </div>
# <p id="letterCount"></p>
# </div>
# <button class="primaryBtn desktopOnly" type="submit">Search</button>
# </div>
# <div class="showsuggestorBox"></div>
# <div class="rctSearchWrap" id="showSearchDiv"></div>
# </div>
# </div>
# </div>
# </div> </header>
# <script type="application/ld+json">{"@context":"http:\/\/schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@type":"WebPage","@id":"https:\/\/www.getmyuni.com","name":"Home"}},{"@type":"ListItem","position":2,"item":{"@type":"WebPage","@id":"https:\/\/www.getmyuni.com\/all-colleges","name":"Colleges"}},{"@type":"ListItem","position":3,"item":{"@type":"WebPage","@id":"https:\/\/www.getmyuni.com\/all-colleges\/uttar-pradesh","name":"Top Colleges in Uttar Pradesh 2024"}}]}</script> <nav class="breadcrumbDiv news">
# <div class="container">
# <ul class="breadcrumb"><li><a href="/" title="Home">Home</a></li>
# <li><a href="/all-colleges" title="Colleges">Colleges</a></li>
# <li class="active">Top Colleges in Uttar Pradesh 2024</li>
# </ul> </div>
# </nav>
# <div class="blueBgDiv mobileOnly">
# <!-- do not delete this -->
# </div>
# <div class="container">
# <div class="college__Landing__New">
# <div class="container top__ads">
# <div class="row">
# <div class="col-md-4">
# <div class="lazy-ad" data-slot="0" id="div-gpt-ad-1614408539431-0" style="height:90px"><script>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1614408539431-0'); });</script></div> </div>
# <div class="col-md-4 desktopOnly">
# <div class="lazy-ad" data-slot="1" id="div-gpt-ad-1614408539431-1" style="height:90px"><script>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1614408539431-1'); });</script></div> </div>
# <div class="col-md-4 desktopOnly">
# <div class="lazy-ad" data-slot="2" id="div-gpt-ad-1614408539431-2" style="height:90px"><script>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1614408539431-2'); });</script></div> </div>
# </div>
# </div>
# <div class="college__Landing__Hero__Section1">
# <div class="college__Landing__Hero__Section pageData pageInfo">
# <h1 class="college__Landing__Hero__Section__Heading">Top Colleges in Uttar Pradesh 2024</h1>
# </div> </div>
# <!--aside>
#                                                         <div class="horizontalRectangle">
#                                                                 <div class="appendAdDiv xs-h100" style="background:#EAEAEA;">
#                                                                                                                                                                                                                                                                 </div>
#                                                         </div>
#                                                         </aside-->
# </div>
# <div class="row">
# <div class="all-college-ajax col-md-3 lg-pr-0" style="min-height: 100vh;">
# </div>
# <div class="col-md-6 mobile__white__bg">
# <div class="filter__selected__container">
# <div class="filterDiv" id="selectedFilters">
# <button class="filter__selected" data-attr="state" id="uttar-pradesh">
#                             Uttar Pradesh<i class="spriteIcon small__close__icon remove-college-filter"></i></button>
# </div>
# <div class="mobile__clear__filter">
# <span class="clearAll" id="clearAllClg">Clear All</span> </div>
# </div>
# <div class="sort__row__container">
# <h3 class="filtered__college_count">Showing 1288 Colleges </h3>
# <div class="sortBy__select2__container desktopOnly">
# <span>Sort By:</span>
# <select id="college-sort" name="college-sort">
# <option value="position">Popularity</option>
# <option selected="" value="rank">Ranking</option>
# <option value="highest_fee">Highest Fees</option>
# <option value="lowest_fee">Lowest Fees</option>
# </select> </div>
# </div>
# <div class="searchBar">
# <input autocomplete="off" class="search-autocomplete1 search-listing" id="autoComplete" placeholder="Search for Colleges" tabindex="1" type="text"/>
# <i class="spriteIcon small__close__icon search-remove"></i>
# <div class="selection"></div>
# </div>
# <div class="filtered__colleges__list">
# <div class="searchedcollegeList">
# <div class="college__card__new" id="search-14">
# <div class="card__header__row">
# <div class="college__detail__grid">
# <img alt="" class="college__image" height="56" loading="" onclick="gmu.url.goto('/college/indian-institute-of-technology-iit-kanpur')" src="https://media.getmyuni.com/azure/college-image/small/indian-institute-of-technology-iit-kanpur.jpg" width="56"/>
# <span class="list__style college__rank mobileOnly"> # 5 NIRF  </span>
# <div class="college__detail__row">
# <h2 class="college__name"><a data-hide="14" href="/college/indian-institute-of-technology-iit-kanpur" title="IIT Kanpur">IIT Kanpur</a></h2>
# <div class="detail__list__mobile">
# <span class="list__style college__location">Kanpur, Uttar Pradesh</span>
# <span class="list__style college__affiliation">Public</span>
# <a class="list__style list__style__rating" href="/college/indian-institute-of-technology-iit-kanpur/reviews" target="_blank" title="Indian Institute of Technology, [IIT] Kanpur Reviews"><span class="list__style college__rating"><span class="spriteIcon__2 review__star__icon"></span>4.4</span> </a>
# <span class="list__style college__rank desktopOnly"> # 5 NIRF  </span> <div class="like__compare__grid mobileOnly">
# <!--span
#                                                                                                         class="heart__icon spriteIcon__2"></span-->
# <span class="compare__icon spriteIcon__2 compareIcon"></span>
# </div>
# </div>
# </div>
# </div>
# <div class="like__compare__grid desktopOnly">
# <!--span class="heart__icon spriteIcon__2"></span-->
# <span class="compare__icon spriteIcon__2 compareIcon"></span>
# </div>
# </div>
# <div class="highlight__cta__row">
# <div class="highlights__grid">
# <div class="highlight__div">
# <span class="highlight__name">Courses
#                                 Offered</span>
# <span class="highlight__value">
# <p> <a href=" https://www.getmyuni.com/college/indian-institute-of-technology-iit-kanpur-courses-fees" title="IIT Kanpur Courses &amp; Fee Details">
#                                                 7 Courses
#                                             </a>
# </p>
# </span>
# </div>
# <div class="highlight__div exam__accepted__div">
# <p class="highlight__name">Exam
#                                 Accepted</p>
# <span class="highlight__value">
# <a href="/exams/cat" target="_blank">CAT</a>
#                                                  ,                                                                                                 <a href="/exams/ceed" target="_blank">CEED</a>
# </span>
# <div class="hover__tooltop">+2                                <span class="hover__card">
# <a href="/exams/iit-jam" target="_blank">IIT JAM</a>,<a href="/exams/jee-main" target="_blank">JEE Main</a>
# </span>
# </div>
# </div>
# <div class="desktopOnly"></div>
# <div class="highlight__div">
# <span class="highlight__name">Tuition
#                                 Fees Range</span>
# <span class="highlight__value">
#                                 ₹12 K-10 L                            </span>
# </div>
# <div class="highlight__div">
# <span class="highlight__name">Accreditation</span>
# <span class="highlight__value">
#                                                                                 NIRF
#                                         <div class="hover__tooltop"> <span class="hover__card">
# </span>
# </div>
# </span>
# <!--span class="highlight__value"> //!empty($model['median_salary']) ? '₹' . CollegeHelper::feesFormat(floor($model['median_salary'])) : '-/-' ?></span!-->
# </div>
# <div class="highlight__div"></div>
# </div>
# <div class="cta__grid">
# <div class="cta__div lead-cta-college-filter-2 leadFilterData download__brochure" data-cityid="745" data-course="" data-ctalocation="colleges_listing_indian-institute-of-technology-iit-kanpur_card_right_cta_web" data-description="IIT Kanpur, Kanpur" data-entity="college" data-filter="college-listing" data-image="https://media.getmyuni.com/azure/college-image/small/indian-institute-of-technology-iit-kanpur.jpg" data-lead_cta="21" data-slug="14" data-stateid="6" data-stream="" data-title="Sign-up to Apply">
# </div>
# <div class="cta__div lead-cta-college-filter-1 leadFilterData primaryBtn" data-cityid="745" data-course="" data-ctalocation="colleges_listing_indian-institute-of-technology-iit-kanpur_card_left_cta_web" data-description="IIT Kanpur, Kanpur" data-entity="college" data-filter="college-listing" data-image="https://media.getmyuni.com/azure/college-image/small/indian-institute-of-technology-iit-kanpur.jpg" data-lead_cta="23" data-slug="14" data-stateid="6" data-stream="" data-title="Sign-up to Download">
# </div>
# </div>
# </div>
# </div>
# <div class="college__card__new" id="search-185">
# <div class="card__header__row">
# <div class="college__detail__grid">
# <img alt="" class="college__image" height="56" loading="" onclick="gmu.url.goto('/college/banaras-hindu-university-bhu-varanasi')" src="https://media.getmyuni.com/azure/college-image/small/banaras-hindu-university-bhu-varanasi.webp" width="56"/>
# <span class="list__style college__rank mobileOnly"> # 11 NIRF  </span>
# <div class="college__detail__row">
# <h2 class="college__name"><a data-hide="185" href="/college/banaras-hindu-university-bhu-varanasi" title="BHU">BHU</a></h2>
# <div class="detail__list__mobile">
# <span class="list__style college__location">Varanasi, Uttar Pradesh</span>
# <span class="list__style college__affiliation">Public</span>
# <a class="list__style list__style__rating" href="/college/banaras-hindu-university-bhu-varanasi/reviews" target="_blank" title="Banaras Hindu University, [BHU] Varanasi Reviews"><span class="list__style college__rating"><span class="spriteIcon__2 review__star__icon"></span>4.0</span> </a>
# <span class="list__style college__rank desktopOnly"> # 11 NIRF  </span> <div class="like__compare__grid mobileOnly">
# <!--span
#                                                                                                         class="heart__icon spriteIcon__2"></span-->
# <span class="compare__icon spriteIcon__2 compareIcon"></span>
# </div>
# </div>
# </div>
# </div>
# <div class="like__compare__grid desktopOnly">
# <!--span class="heart__icon spriteIcon__2"></span-->
# <span class="compare__icon spriteIcon__2 compareIcon"></span>
# </div>
# </div>
# <div class="highlight__cta__row">
# <div class="highlights__grid">
# <div class="highlight__div">
# <span class="highlight__name">Courses
#                                 Offered</span>
# <span class="highlight__value">
# <p> <a href=" https://www.getmyuni.com/college/banaras-hindu-university-bhu-varanasi-courses-fees" title="BHU Courses &amp; Fee Details">
#                                                 48 Courses
#                                             </a>
# </p>
# </span>
# </div>
# <div class="highlight__div exam__accepted__div">
# <p class="highlight__name">Exam
#                                 Accepted</p>
# <span class="highlight__value">
# <a href="/exams/bhu-pet" target="_blank">BHU PET</a>
#                                                  ,                                                                                                 <a href="/exams/bhu-uet" target="_blank">BHU UET</a>
# </span>
# <div class="hover__tooltop">+8                                <span class="hover__card">
# <a href="/exams/blat" target="_blank">BLAT</a>,<a href="/exams/cat" target="_blank">CAT</a>,<a href="/exams/cucet" target="_blank">CUET</a>,<a href="/exams/cuet-pg" target="_blank">CUET PG</a>,<a href="/exams/neet" target="_blank">NEET</a>,<a href="/exams/neet-mds" target="_blank">NEET MDS</a>,<a href="/exams/neet-pg" target="_blank">NEET PG</a>,<a href="/exams/neet-ss" target="_blank">NEET SS</a>
# </span>
# </div>
# </div>
# <div class="desktopOnly"></div>
# <div class="highlight__div">
# <span class="highlight__name">Tuition
#                                 Fees Range</span>
# <span class="highlight__value">
#                                 ₹500 -1.20 L                            </span>
# </div>
# <div class="highlight__div">
# <span class="highlight__name">Accreditation</span>
# <span class="highlight__value">
#                                                                                 NAAC
#                                         <div class="hover__tooltop"> <span class="hover__card">
# </span>
# </div>
# </span>
# <!--span class="highlight__value"> //!empty($model['median_salary']) ? '₹' . CollegeHelper::feesFormat(floor($model['median_salary'])) : '-/-' ?></span!-->
# </div>
# <div class="highlight__div"></div>
# </div>
# <div class="cta__grid">
# <div class="cta__div lead-cta-college-filter-2 leadFilterData download__brochure" data-cityid="782" data-course="" data-ctalocation="colleges_listing_banaras-hindu-university-bhu-varanasi_card_right_cta_web" data-description="BHU, Varanasi" data-entity="college" data-filter="college-listing" data-image="https://media.getmyuni.com/azure/college-image/small/banaras-hindu-university-bhu-varanasi.webp" data-lead_cta="21" data-slug="185" data-stateid="6" data-stream="" data-title="Sign-up to Apply">
# </div>
# <div class="cta__div lead-cta-college-filter-1 leadFilterData primaryBtn" data-cityid="782" data-course="" data-ctalocation="colleges_listing_banaras-hindu-university-bhu-varanasi_card_left_cta_web" data-description="BHU, Varanasi" data-entity="college" data-filter="college-listing" data-image="https://media.getmyuni.com/azure/college-image/small/banaras-hindu-university-bhu-varanasi.webp" data-lead_cta="23" data-slug="185" data-stateid="6" data-stream="" data-title="Sign-up to Download">
# </div>
# </div>
# </div>
# </div>
# <div class="filter__by__exam hide__widget">
# <div class="heading__row">
# <h3 class="exam__row__heading">Filter By Stream</h3>
# <!--div class="view__all__exams">View All
#                     <span class="spriteIcon__2 blue__angle__icon"></span>
#             </div-->
# </div>
# <ul class="exam__list">
# <a href="https://www.getmyuni.com/arts-colleges/uttar-pradesh" style="text-decoration:none; cursor:pointer; " target="_blank"><li>Arts (485)</li></a>
# <a href="https://www.getmyuni.com/management-colleges/uttar-pradesh" style="text-decoration:none; cursor:pointer; " target="_blank"><li>Management (592)</li></a>
# <a href="https://www.getmyuni.com/education-colleges/uttar-pradesh" style="text-decoration:none; cursor:pointer; " target="_blank"><li>Education (566)</li></a>
# <a href="https://www.getmyuni.com/engineering-colleges/uttar-pradesh" style="text-decoration:none; cursor:pointer; " target="_blank"><li>Engineering (383)</li></a>
# <a href="https://www.getmyuni.com/science-colleges/uttar-pradesh" style="text-decoration:none; cursor:pointer; " target="_blank"><li>Science (345)</li></a>
# <a href="https://www.getmyuni.com/computer-colleges/uttar-pradesh" style="text-decoration:none; cursor:pointer; " target="_blank"><li>Computer (307)</li></a>
# <a href="https://www.getmyuni.com/commerce-colleges/uttar-pradesh" style="text-decoration:none; cursor:pointer; " target="_blank"><li>Commerce (263)</li></a>
# <a href="https://www.getmyuni.com/pharmacy-colleges/uttar-pradesh" style="text-decoration:none; cursor:pointer; " target="_blank"><li>Pharmacy (118)</li></a>
# </ul>
# </div>
# <div class="college__card__new" id="search-61">
# <div class="card__header__row">
# <div class="college__detail__grid">
# <img alt="" class="college__image" height="56" loading="" onclick="gmu.url.goto('/college/aligarh-muslim-university-amu-aligarh')" src="https://media.getmyuni.com/azure/college-image/small/aligarh-muslim-university-amu-aligarh.jpg" width="56"/>
# <span class="list__style college__rank mobileOnly"> # 16 NIRF  </span>
# <div class="college__detail__row">
# <h2 class="college__name"><a data-hide="61" href="/college/aligarh-muslim-university-amu-aligarh" title="AMU">AMU</a></h2>
# <div class="detail__list__mobile">
# <span class="list__style college__location">Aligarh, Uttar Pradesh</span>
# <span class="list__style college__affiliation">Public</span>
# <a class="list__style list__style__rating" href="/college/aligarh-muslim-university-amu-aligarh/reviews" target="_blank" title="Aligarh Muslim University, [AMU] Aligarh Reviews"><span class="list__style college__rating"><span class="spriteIcon__2 review__star__icon"></span>3.3</span> </a>
# <span class="list__style college__rank desktopOnly"> # 16 NIRF  </span> <div class="like__compare__grid mobileOnly">
# <!--span
#                                                                                                         class="heart__icon spriteIcon__2"></span-->
# <span class="compare__icon spriteIcon__2 compareIcon"></span>
# </div>
# </div>
# </div>
# </div>
# <div class="like__compare__grid desktopOnly">
# <!--span class="heart__icon spriteIcon__2"></span-->
# <span class="compare__icon spriteIcon__2 compareIcon"></span>
# </div>
# </div>
# <div class="highlight__cta__row">
# <div class="highlights__grid">
# <div class="highlight__div">
# <span class="highlight__name">Courses
#                                 Offered</span>
# <span class="highlight__value">
# <p> <a href=" https://www.getmyuni.com/college/aligarh-muslim-university-amu-aligarh-courses-fees" title="AMU Courses &amp; Fee Details">
#                                                 32 Courses
#                                             </a>
# </p>
# </span>
# </div>
# <div class="highlight__div exam__accepted__div">
# <p class="highlight__name">Exam
#                                 Accepted</p>
# <span class="highlight__value">
# <a href="/exams/nata" target="_blank">NATA</a>
#                                                  ,                                                                                                 <a href="/exams/neet" target="_blank">NEET</a>
# </span>
# <div class="hover__tooltop"> <span class="hover__card">
# </span>
# </div>
# </div>
# <div class="desktopOnly"></div>
# <div class="highlight__div">
# <span class="highlight__name">Tuition
#                                 Fees Range</span>
# <span class="highlight__value">
#                                 ₹15 K-13.47 L                            </span>
# </div>
# <div class="highlight__div">
# <span class="highlight__name">Accreditation</span>
# <span class="highlight__value">
#                                                                                 NAAC                                                 ,                                                                                                  NAAC-A
#                                         <div class="hover__tooltop"> <span class="hover__card">
# </span>
# </div>
# </span>
# <!--span class="highlight__value"> //!empty($model['median_salary']) ? '₹' . CollegeHelper::feesFormat(floor($model['median_salary'])) : '-/-' ?></span!-->
# </div>
# <div class="highlight__div"></div>
# </div>
# <div class="cta__grid">
# <div class="cta__div lead-cta-college-filter-2 leadFilterData download__brochure" data-cityid="699" data-course="" data-ctalocation="colleges_listing_aligarh-muslim-university-amu-aligarh_card_right_cta_web" data-description="AMU, Aligarh" data-entity="college" data-filter="college-listing" data-image="https://media.getmyuni.com/azure/college-image/small/aligarh-muslim-university-amu-aligarh.jpg" data-lead_cta="21" data-slug="61" data-stateid="6" data-stream="" data-title="Sign-up to Apply">
# </div>
# <div class="cta__div lead-cta-college-filter-1 leadFilterData primaryBtn" data-cityid="699" data-course="" data-ctalocation="colleges_listing_aligarh-muslim-university-amu-aligarh_card_left_cta_web" data-description="AMU, Aligarh" data-entity="college" data-filter="college-listing" data-image="https://media.getmyuni.com/azure/college-image/small/aligarh-muslim-university-amu-aligarh.jpg" data-lead_cta="23" data-slug="61" data-stateid="6" data-stream="" data-title="Sign-up to Download">
# </div>
# </div>
# </div>
# </div>
# <div class="college__card__new" id="search-583">
# <div class="card__header__row">
# <div class="college__detail__grid">
# <img alt="" class="college__image" height="56" loading="" onclick="gmu.url.goto('/college/indian-institute-of-technology-iit-varanasi')" src="https://media.getmyuni.com/azure/college-image/small/indian-institute-of-technology-iit-varanasi.jpg" width="56"/>
# <span class="list__style college__rank mobileOnly"> # 30 NIRF  </span>
# <div class="college__detail__row">
# <h2 class="college__name"><a data-hide="583" href="/college/indian-institute-of-technology-iit-varanasi" title="IIT Varanasi (BHU)">IIT Varanasi (BHU)</a></h2>
# <div class="detail__list__mobile">
# <span class="list__style college__location">Varanasi, Uttar Pradesh</span>
# <span class="list__style college__affiliation">Public</span>
# <a class="list__style list__style__rating" href="/college/indian-institute-of-technology-iit-varanasi/reviews" target="_blank" title="IIT Varanasi - Indian Institute of Technology Reviews"><span class="list__style college__rating"><span class="spriteIcon__2 review__star__icon"></span>3.4</span> </a>
# <span class="list__style college__rank desktopOnly"> # 30 NIRF  </span> <div class="like__compare__grid mobileOnly">
# <!--span
#                                                                                                         class="heart__icon spriteIcon__2"></span-->
# <span class="compare__icon spriteIcon__2 compareIcon"></span>
# </div>
# </div>
# </div>
# </div>
# <div class="like__compare__grid desktopOnly">
# <!--span class="heart__icon spriteIcon__2"></span-->
# <span class="compare__icon spriteIcon__2 compareIcon"></span>
# </div>
# </div>
# <div class="highlight__cta__row">
# <div class="highlights__grid">
# <div class="highlight__div">
# <span class="highlight__name">Courses
#                                 Offered</span>
# <span class="highlight__value">
# <p> <a href=" https://www.getmyuni.com/college/indian-institute-of-technology-iit-varanasi-courses-fees" title="IIT Varanasi (BHU) Courses &amp; Fee Details">
#                                                 7 Courses
#                                             </a>
# </p>
# </span>
# </div>
# <div class="highlight__div exam__accepted__div">
# <p class="highlight__name">Exam
#                                 Accepted</p>
# <span class="highlight__value">
# <a href="/exams/jee-main" target="_blank">JEE Main</a>
# </span>
# <div class="hover__tooltop"> <span class="hover__card">
# </span>
# </div>
# </div>
# <div class="desktopOnly"></div>
# <div class="highlight__div">
# <span class="highlight__name">Tuition
#                                 Fees Range</span>
# <span class="highlight__value">
#                                 ₹40 K-4 L                            </span>
# </div>
# <div class="highlight__div">
# <span class="highlight__name">Accreditation</span>
# <span class="highlight__value">
# <span class="highlight__value"> -/- </span>
# <!--span class="highlight__value"> //!empty($model['median_salary']) ? '₹' . CollegeHelper::feesFormat(floor($model['median_salary'])) : '-/-' ?></span!-->
# </span></div>
# <div class="highlight__div"></div>
# </div>
# <div class="cta__grid">
# <div class="cta__div lead-cta-college-filter-2 leadFilterData download__brochure" data-cityid="782" data-course="" data-ctalocation="colleges_listing_indian-institute-of-technology-iit-varanasi_card_right_cta_web" data-description="IIT Varanasi (BHU), Varanasi" data-entity="college" data-filter="college-listing" data-image="https://media.getmyuni.com/azure/college-image/small/indian-institute-of-technology-iit-varanasi.jpg" data-lead_cta="21" data-slug="583" data-stateid="6" data-stream="" data-title="Sign-up to Apply">
# </div>
# <div class="cta__div lead-cta-college-filter-1 leadFilterData primaryBtn" data-cityid="782" data-course="" data-ctalocation="colleges_listing_indian-institute-of-technology-iit-varanasi_card_left_cta_web" data-description="IIT Varanasi (BHU), Varanasi" data-entity="college" data-filter="college-listing" data-image="https://media.getmyuni.com/azure/college-image/small/indian-institute-of-technology-iit-varanasi.jpg" data-lead_cta="23" data-slug="583" data-stateid="6" data-stream="" data-title="Sign-up to Download">
# </div>
# </div>
# </div>
# </div>
# <div class="sponser-list hide__widget">
# </div>
# <div class="cta__banner hide__widget">
# <p>Confused about which college or exam to opt for?</p>
# <p>Chat with our counselor Get your personalised list of
#                         colleges &amp; exams </p>
# <div class="cta__div primaryBtn brochureBtn leadFilterData predict-my-college-cta" data-cityid="782" data-course="" data-ctalocation="colleges_listing_single_top_cta_web" data-description="" data-entity="college" data-filter="college-listing" data-image="https://media.getmyuni.com/azure/college-image/small/indian-institute-of-technology-iit-varanasi.jpg" data-lead_cta="22" data-slug="583" data-stateid="6" data-stream="" data-title="Get Counselling from experts, free of cost !">
# </div>
# <img alt="banner image" src="../../yas/images/cta-banner.png"/>
# </div>
# <div class="searchedcollegeListGrid">
# <div class="college__card__new featured__card" id="search-42149">
# <div class="card__header__row">
# <div class="college__detail__grid">
# <img alt="" class="college__image" height="56" loading="" onclick="gmu.url.goto('/college/vignan-online')" src="https://media.getmyuni.com/yas/images/gmu-icon.svg" width="56"/>
# <div class="college__detail__row">
# <h2 class="college__name"><a data-hide="42149" href="/college/vignan-online" title="Vignan Online">Vignan Online</a></h2>
# <div class="detail__list__mobile">
# <span class="list__style college__location">Guntur, Andhra Pradesh</span>
# <span class="list__style college__affiliation"></span>
# <div class="like__compare__grid mobileOnly">
# <!--span
#                                                                                                         class="heart__icon spriteIcon__2"></span-->
# <span class="compare__icon spriteIcon__2 compareIcon"></span>
# </div>
# </div>
# </div>
# </div>
# <div class="like__compare__grid desktopOnly">
# <!--span class="heart__icon spriteIcon__2"></span-->
# <span class="compare__icon spriteIcon__2 compareIcon"></span>
# </div>
# </div>
# <div class="highlight__cta__row">
# <div class="highlights__grid">
# <div class="highlight__div">
# <span class="highlight__name">Courses
#                                                                                         Offered</span>
# <span class="highlight__value">
# <p> <a href=" https://www.getmyuni.com/college/vignan-online-courses-fees" title="Vignan Online Courses &amp; Fee Details">
#                                                                                         3 Courses
#                                             </a>
# </p>
# </span>
# </div>
# <div class="highlight__div exam__accepted__div">
# <p class="highlight__name">Exam
#                                                                                         Accepted</p>
# <span class="highlight__value">
# <span class="highlight__value"> -/-</span>
# </span></div>
# <div class="desktopOnly"></div>
# <div class="highlight__div">
# <span class="highlight__name">Tuition
#                                                                                         Fees Range</span>
# <span class="highlight__value">
#                                                                                 ₹1.10 L-1.35 L                                                                                </span>
# </div>
# <div class="highlight__div">
# <span class="highlight__name">Accreditation</span>
# <span class="highlight__value">
# <span class="highlight__value">   -/-  </span>
# <!--span class="highlight__value">//!empty($model['median_salary']) ? '₹' . CollegeHelper::feesFormat(floor($model['median_salary'])) : '-/-' ?></span!-->
# </span></div>
# <div class="highlight__div"></div>
# </div>
# <div class="cta__grid">
# <div class="cta__div lead-cta-college-filter-2 leadFilterData download__brochure" data-cityid="14" data-course="" data-ctalocation="colleges_listing_vignan-online_card_right_cta_web" data-description="Vignan Online, Guntur" data-entity="college" data-filter="college-listing" data-image="https://media.getmyuni.com/azure/college-image/small/" data-lead_cta="21" data-slug="42149" data-stateid="3" data-stream="" data-title="Sign-up to Apply"></div>
# <div class="cta__div lead-cta-college-filter-1 leadFilterData primaryBtn" data-cityid="14" data-course="" data-ctalocation="colleges_listing_vignan-online_card_left_cta_web" data-description="Vignan Online, Guntur" data-entity="college" data-filter="college-listing" data-image="https://media.getmyuni.com/azure/college-image/small/" data-lead_cta="23" data-slug="42149" data-stateid="3" data-stream="" data-title="Sign-up to Download"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="college__card__new" id="search-20">
# <div class="card__header__row">
# <div class="college__detail__grid">
# <img alt="" class="college__image" height="56" loading="" onclick="gmu.url.goto('/college/amity-university-noida')" src="https://media.getmyuni.com/azure/college-image/small/amity-university-noida.jpg" width="56"/>
# <span class="list__style college__rank mobileOnly"> # 49 NIRF  </span>
# <div class="college__detail__row">
# <h2 class="college__name"><a data-hide="20" href="/college/amity-university-noida" title="Amity University Noida">Amity University Noida</a></h2>
# <div class="detail__list__mobile">
# <span class="list__style college__location">Noida, Uttar Pradesh</span>
# <span class="list__style college__affiliation">Private</span>
# <a class="list__style list__style__rating" href="/college/amity-university-noida/reviews" target="_blank" title="Amity University, Noida Reviews"><span class="list__style college__rating"><span class="spriteIcon__2 review__star__icon"></span>3.7</span> </a>
# <span class="list__style college__rank desktopOnly"> # 49 NIRF  </span> <div class="like__compare__grid mobileOnly">
# <!--span
#                                                                                                         class="heart__icon spriteIcon__2"></span-->
# <span class="compare__icon spriteIcon__2 compareIcon"></span>
# </div>
# </div>
# </div>
# </div>
# <div class="like__compare__grid desktopOnly">
# <!--span class="heart__icon spriteIcon__2"></span-->
# <span class="compare__icon spriteIcon__2 compareIcon"></span>
# </div>
# </div>
# ...
# <p class="feedback-text">Thanks for FeedBack </p>
# </div>
# </form>
# </div>
# <!-- scroll to top -->
# <img class="scrollToTop" loading="lazy" src="/yas/images/scroll_to_top.webp"/>
# <style>
#     /* .whatsappIntegrationIcon {
#         position: fixed;
#         bottom: 130px;
#         right: 17px;
#         z-index: 10;
#         width: 60px;
#         height: 60px;
#         transform: translateY(50px);
#     }
#
#     @media (max-width: 1023px) {
#         .whatsappIntegrationIcon {
#             bottom: 118px;
#             right: 19px;
#         }
#     } */
#
#     .whatsappIntegrationIcon {
#         background-color: #29d74c;
#         width: 60px;
#         height: 60px;
#         padding: 5px;
#         justify-content: center;
#         display: flex;
#         align-items: center;
#         flex-direction: column;
#         border-radius: 50%;
#         cursor: pointer;
#         position: fixed;
#         bottom: 69px;
#         right: 30px;
#         z-index: 10;
#         animation-name: pulse;
#         animation-duration: 1.5s;
#         animation-timing-function: ease-out;
#         animation-iteration-count: infinite;
#     }
#
#     @keyframes pulse {
#         0% {
#             -webkit-transform: scale(1);
#             -ms-transform: scale(1);
#             transform: scale(1);
#         }
#
#         50% {
#             -webkit-transform: scale(1.1);
#             -ms-transform: scale(1.1);
#             transform: scale(1.1);
#         }
#
#         100% {
#             -webkit-transform: scale(1);
#             -ms-transform: scale(1);
#             transform: scale(1);
#         }
#     }
#
#     .whatsappIntegrationIcon img {
#         width: 30px;
#         height: 30px;
#         color: transparent;
#
#     }
#
#     @media (max-width: 1023px) {
#         .whatsappIntegrationIcon {
#             right: 20px;
#         }
#     }
# </style>
# <a class="whatsappIntegrationIcon" href="https://api.whatsapp.com/send?phone=+919910525319&amp;text= Hi! I am looking for colleges to take admission in 2024. Can you help connect me to a college expert?" rel="nofollow" target="_blank">
# <img id="shareWp" src="/yas/images/WhatsApp.webp"/>
# </a> <!--div class="extended__footer">
#                 <section class="extended__footer__section">
#                         <h4 class="accordian__label">MBA</h4>
#                         <ul class="accordian__expand">
#                                 <li>MBA</li>
#                                 <li>Top MBA Colleges</li>
#                                 <li>Executive MBA Colleges</li>
#                                 <li>CAT</li>
#                                 <li>MAT</li>
#                         </ul>
#                 </section>
#                 <section class="extended__footer__section">
#                         <h4 class="accordian__label">Engineering</h4>
#                         <ul class="accordian__expand">
#                                 <li>Engineering</li>
#                                 <li>Top Engineering Colleges</li>
#                                 <li>Executive Engineering Colleges</li>
#                                 <li>JEE MAINS</li>
#                                 <li>ADVANCe</li>
#                         </ul>
#                 </section>
#                 <section class="extended__footer__section">
#                         <h4 class="accordian__label">Medicine</h4>
#                         <ul class="accordian__expand">
#                                 <li>Engineering</li>
#                                 <li>Top Engineering Colleges</li>
#                                 <li>Executive Engineering Colleges</li>
#                                 <li>JEE MAINS</li>
#                                 <li>ADVANCe</li>
#                                 <li>Engineering</li>
#                                 <li>Top Engineering Colleges</li>
#                                 <li>Executive Engineering Colleges</li>
#                                 <li>JEE MAINS</li>
#                                 <li>ADVANCe</li>
#                         </ul>
#                 </section>
#                 <section class="extended__footer__section">
#                         <h4 class="accordian__label">Others</h4>
#                         <ul class="accordian__expand">
#                                 <li>Animation</li>
#                                 <li>Top B,Sc Colleges</li>
#                                 <li>Executive Engineering Colleges</li>
#                                 <li>Mass</li>
#                                 <li>Law</li>
#                                 <li>Design</li>
#                                 <li>ABC Colleges</li>
#                                 <li>Executive Engineering Colleges</li>
#                                 <li>JEE MAINS</li>
#                                 <li>ADVANCe</li>
#                         </ul>
#                 </section>
#                 <section class="extended__footer__section">
#                         <h4 class="accordian__label">Others</h4>
#                         <ul class="accordian__expand">
#                                 <li>Animation</li>
#                                 <li>Top B,Sc Colleges</li>
#                                 <li>Executive Engineering Colleges</li>
#                                 <li>Mass</li>
#                                 <li>Law</li>
#                                 <li>Design</li>
#                                 <li>ABC Colleges</li>
#                                 <li>Executive Engineering Colleges</li>
#                                 <li>JEE MAINS</li>
#                                 <li>ADVANCe</li>
#                         </ul>
#                 </section>
#                 <section class="extended__footer__section">
#                         <h4 class="accordian__label">Others</h4>
#                         <ul class="accordian__expand">
#                                 <li>Animation</li>
#                                 <li>Top B,Sc Colleges</li>
#                                 <li>Executive Engineering Colleges</li>
#                                 <li>Mass</li>
#                                 <li>Law</li>
#                                 <li>Design</li>
#                                 <li>ABC Colleges</li>
#                                 <li>Executive Engineering Colleges</li>
#                                 <li>JEE MAINS</li>
#                                 <li>ADVANCe</li>
#                         </ul>
#                 </section>
#                 <section class="extended__footer__section">
#                         <h4 class="accordian__label">Others</h4>
#                         <ul class="accordian__expand">
#                                 <li>Animation</li>
#                                 <li>Top B,Sc Colleges</li>
#                                 <li>Executive Engineering Colleges</li>
#                                 <li>Mass</li>
#                                 <li>Law</li>
#                                 <li>Design</li>
#                                 <li>ABC Colleges</li>
#                                 <li>Executive Engineering Colleges</li>
#                                 <li>JEE MAINS</li>
#                                 <li>ADVANCe</li>
#                         </ul>
#                 </section>
#                 <section class="extended__footer__section">
#                         <h4 class="accordian__label">Others</h4>
#                         <ul class="accordian__expand">
#                                 <li>Animation</li>
#                                 <li>Top B,Sc Colleges</li>
#                                 <li>Executive Engineering Colleges</li>
#                                 <li>Mass</li>
#                                 <li>Law</li>
#                                 <li>Design</li>
#                                 <li>ABC Colleges</li>
#                                 <li>Executive Engineering Colleges</li>
#                                 <li>JEE MAINS</li>
#                                 <li>ADVANCe</li>
#                         </ul>
#                 </section>
#
#         </div-->
# <footer class="pageFooter">
# <div class="footerPrimarySection">
# <div class="container">
# <div class="row">
# <img alt="Getmyuni Logo" class="lazyload" data-src="https://media.getmyuni.com/yas/images/gmulogo.png" height="40" loading="lazy" src="https://media.getmyuni.com/yas/images/gmulogo.png" width="172"/>
# <div>
# <ul class="socialMedia">
# <li>Connect with us</li>
# <li><a class="spriteIcon fbIcon" href="https://www.facebook.com/getmyuniedu" rel="noopener nofollow" target="_blank" title="Facebook"></a></li>
# <li><a class="spriteIcon twitterIcon" href="https://twitter.com/getmyuniedu" rel="noopener nofollow" target="_blank" title="Twitter"></a></li>
# <li><a class="spriteIcon instaIcon" href="https://www.instagram.com/getmyuni/" rel="noopener nofollow" target="_blank" title="Instagram"></a>
# </li>
# <li><a class="spriteIcon linkdIn" href="https://www.linkedin.com/company/getmyuni" rel="noopener nofollow" target="_blank" title="Linkedin"></a></li>
# <li><a class="spriteIcon youtubeIcon" href="https://www.youtube.com/channel/UCvczFiMv9OZwYkFydoNdMCA" rel="noopener nofollow" target="_blank" title="Youtube"></a>
# </li>
# </ul>
# <ul class="contactInfo">
# <li><span class="spriteIcon phoneIcon"></span><a href="tel:+918884099411" title="+918884099411">+91 8884099411</a>
# </li>
# <li><span class="spriteIcon whiteMailIcon"></span> <a href="mailTo:contact@getmyuni.com" title="contact@getmyuni.com">contact@getmyuni.com</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="footerSecondSection">
# <div class="container">
# <div class="row">
# <ul>
# <li><a href="https://www.getmyuni.com/about-us" title="About Us">About Us</a></li>
# <li><a href="https://www.getmyuni.com/contact-us" title="Contact Us">Contact Us</a></li>
# <li><a href="https://www.getmyuni.com/privacy-policy" title="Privacy Policy">Privacy Policy</a></li>
# <li><a href="https://www.getmyuni.com/terms-and-conditions" title="Terms &amp; Conditions">Terms &amp; Conditions</a></li>
# </ul>
# <p class="copyrightsText">
#                     © 2024 Getmyuni.com. All Rights Reserved.                </p>
# </div>
# </div>
# </div>
# </footer>
# <script src="/yas/js/version2/ajax/libs/js/jquery.min.js?v=1707645615"></script>
# <script src="/yas/assets/99c91b8d/yii.js?v=1677236426"></script>
# <script defer="" src="/yas/js/version2/ajax/libs/js/select2.min.js?v=1707645615"></script>
# <script src="/yas/js/version2/ajax/libs/js/jquery-ui.min.js?v=1707645615"></script>
# <script src="/yas/js/version2/ajax/libs/js/slick.min.js?v=1707645615"></script>
# <script src="/yas/js/version2/min/college-filter-page.js?v=1729774232"></script>
# <script defer="" src="/yas/js/version2/min/global.js?v=1729774232"></script>
# <script defer="" src="/yas/js/version2/min/script.js?v=1729774232"></script>
# <script defer="" src="/yas/js/version2/min/filter_script.js?v=1729774232"></script>
# <script defer="" src="/yas/js/version2/min/login.js?v=1729774232"></script> <div id="lead-form-js-new" style="display: none"></div>
# <div id="login-form-js" style="display: none"></div>
# <div id="fees-breakup" style="display: none;"></div>
# <!-- <div id="banner-popup"></div> -->
# <!-- Loading Icon -->
# <div class="pageLoader" id="filter-loader">
# <div class="pageLoaderDiv">
# <div class="circle"></div>
# <p class="loadText">Loading...</p>
# </div>
# </div>
# <script>
#         function hideAdSection(e) {
#             var n = e.slot.getSlotElementId();
#             if ("" != n || "undefined" != n) {
#                 var d = "",
#                     t = "",
#                     l = "";
#                 if (d = document.getElementById(n).parentNode, (null != d || "undefined" != d || "" != d)) {
#                     d.style.display = "none";
#                 }
#             }
#         }
#         window.addEventListener('load', function() {
#             setTimeout(() => {
#                 const script = document.createElement('script');
#                 script.src = 'https://securepubads.g.doubleclick.net/tag/js/gpt.js';
#                 document.getElementsByTagName('head')[0].appendChild(script);
#                 $('.lazy-ad').each(function() {
#                     var refreshed = false;
#                     var threshold = 640;
#                     var element = $(this);
#                     var scrollId = element.data('slot');
#                     if (element.offset().top < threshold) {
#                         if (!refreshed) {
#                             googletag.cmd.push(function() {
#                                 googletag.pubads().refresh([gptAdSlots[scrollId]]);
#                             });
#                             refreshed = true;
#                         }
#                     } else {
#                         var listener = function() {
#                             var adSlotPos = element.offset().top;
#                             var adAlmostVisibleScrollValue = adSlotPos - 700;
#                             if (window.scrollY >= adAlmostVisibleScrollValue && !refreshed) {
#                                 googletag.cmd.push(function() {
#                                     googletag.pubads().refresh([gptAdSlots[scrollId]]);
#                                 });
#                                 refreshed = true;
#                                 window.removeEventListener('scroll', listener);
#                             }
#                         }
#                         window.addEventListener('scroll', listener);
#                     }
#                 })
#             }, 7000);
#         });
#     </script>
# <script>
#         (function() {
#             var base_url = window.location.origin;
#             var cssAutoComplete = document.createElement('link');
#             // cssAutoComplete.href = 'https://cdnjs.cloudflare.com/ajax/libs/tarekraafat-autocomplete.js/8.3.0/css/autoComplete.min.css';
#             cssAutoComplete.href = base_url + '/yas/css/version2/ajax/libs/css/autoComplete.min.css';
#             cssAutoComplete.rel = 'stylesheet';
#             cssAutoComplete.type = 'text/css';
#             document.getElementsByTagName('head')[0].appendChild(cssAutoComplete);
#
#             var cssSelect2 = document.createElement('link');
#             // cssSelect2.href = 'https://cdnjs.cloudflare.com/ajax/libs/select2/4.1.0-rc.0/css/select2.min.css';
#             cssSelect2.href = base_url + '/yas/css/version2/ajax/libs/css/select2.min.css';
#             cssSelect2.rel = 'stylesheet';
#             cssSelect2.type = 'text/css';
#             document.getElementsByTagName('head')[0].appendChild(cssSelect2);
#
#             var cssSlick = document.createElement('link');
#             // cssSlick.href = 'https://cdnjs.cloudflare.com/ajax/libs/slick-carousel/1.8.1/slick.min.css';
#             cssSlick.href = base_url + '/yas/css/version2/ajax/libs/css/slick.min.css';
#             cssSlick.rel = 'stylesheet';
#             cssSlick.type = 'text/css';
#             document.getElementsByTagName('head')[0].appendChild(cssSlick);
#
#             var jsAutoComplete = document.createElement('script');
#             // jsAutoComplete.src = "https://cdnjs.cloudflare.com/ajax/libs/tarekraafat-autocomplete.js/8.3.0/js/autoComplete.min.js";
#             jsAutoComplete.src = base_url + "/yas/js/version2/ajax/libs/js/autoComplete.min.js";
#             var script = document.getElementsByTagName('script')[0];
#             script.defer = true;
#             script.parentNode.insertBefore(jsAutoComplete, script);
#
#         })();
#
#         if ('loading' in HTMLImageElement.prototype) {
#             const images = document.querySelectorAll('img[loading="lazy"]');
#             images.forEach(img => {
#                 img.src = img.dataset.src ?? img.src;
#             });
#         } else {
#             var base_url = window.location.origin;
#             // Dynamically import the LazySizes library
#             const script = document.createElement('script');
#             // script.src ='https://cdnjs.cloudflare.com/ajax/libs/lazysizes/5.1.2/lazysizes.min.js';
#             script.src = base_url + '/yas/js/version2/ajax/libs/js/lazysizes.min.js';
#             script.defer = true;
#             document.body.appendChild(script);
#         }
#     </script>
#
# </html>

# %%
names=soup.find_all('h2',class_='college__name')
city=soup.find_all('div',class_='detail__list__mobile')
fees=soup.find_all('span',class_='highlight__value')

# %%
college_names = []
college_cities = []
college_fees = []

# %%
for name, city, fee in zip(names, city, fees):
    college_names.append(name.text.strip())
    college_cities.append(city.text.strip())
    college_fees.append(fee.text.strip())

# %%
college_data = {'college_names':college_names, 'college_cities':college_cities, 'college_fees':college_fees}
print(college_data)
# Out:
# {'college_names': ['IIT Kanpur', 'BHU', 'AMU', 'IIT Varanasi (BHU)', 'Vignan Online', 'Amity University Noida', 'KGMU', 'Banasthali Vidyapith', 'MNNIT Allahabad', 'IIIT Allahabad', 'Amity University, Noida', 'IMS Noida', 'Galgotias', 'IMS Engineering College', 'Shri Ram Murti Smarak College of Engineering and Technology', 'ABS Noida', 'HBTU', 'IIIT Delhi', 'Institute of Management Studies, BHU', 'Jaipuria Institute of Management Noida', 'PSIT Kanpur', 'ITS Ghaziabad', 'Sri Ram Murti Smarak International Business School (SRMS)', 'Doon Business School (DBS)', 'GLA University', 'IIM Lucknow', 'Faculty of Engineering, Dayalbagh Educational Institute', 'Jaipuria Institute of Management Lucknow'], 'college_cities': ['Kanpur, Uttar Pradesh\nPublic\n4.4 \n # 5 NIRF', 'Varanasi, Uttar Pradesh\nPublic\n4.0 \n # 11 NIRF', 'Aligarh, Uttar Pradesh\nPublic\n3.3 \n # 16 NIRF', 'Varanasi, Uttar Pradesh\nPublic\n3.4 \n # 30 NIRF', 'Guntur, Andhra Pradesh', 'Noida, Uttar Pradesh\nPrivate\n3.7 \n # 49 NIRF', 'Lucknow, Uttar Pradesh\nPublic\n4.1 \n # 88 NIRF', 'Lucknow, Uttar Pradesh\nPrivate\n3', 'Allahabad, Uttar Pradesh\nPublic\n3.8', 'Allahabad, Uttar Pradesh\nPublic\n4.0', 'Greater Noida, Uttar Pradesh\nPrivate\n4.4', 'Noida, Uttar Pradesh\nPrivate\n3.3', 'Noida, Uttar Pradesh\nPrivate\n2.4', 'Ghaziabad, Uttar Pradesh\nPrivate\n3.7', 'Bareilly, Uttar Pradesh\nPrivate\n2.9', 'Noida, Uttar Pradesh\nPrivate\n4.0', 'Kanpur, Uttar Pradesh\nPublic\n3.3', 'Amroha, Uttar Pradesh\nPrivate\n4.3', 'Varanasi, Uttar Pradesh\nPublic\n4.0', 'Noida, Uttar Pradesh\nPrivate\n3.7', 'Kanpur, Uttar Pradesh\nPrivate\n4.4', 'Ghaziabad, Uttar Pradesh\nPrivate\n3.5', 'Unnao, Uttar Pradesh\nPrivate', 'Kanpur, Uttar Pradesh\nPrivate\n3.4', 'Mathura, Uttar Pradesh\nPrivate\n3.2', 'Lucknow, Uttar Pradesh\nPublic\n4.3', 'Agra, Uttar Pradesh\nPrivate\n3.9', 'Lucknow, Uttar Pradesh\nPrivate\n3.9'], 'college_fees': ['7 Courses', 'CAT\n                                                 ,                                                                                                 CEED', '₹12 K-10 L', 'NIRF', '48 Courses', 'BHU PET\n                                                 ,                                                                                                 BHU UET', '₹500 -1.20 L', 'NAAC', '32 Courses', 'NATA\n                                                 ,                                                                                                 NEET', '₹15 K-13.47 L', 'NAAC                                                 ,                                                                                                  NAAC-A', '7 Courses', 'JEE Main', '₹40 K-4 L', '-/-', '-/-', '3 Courses', '-/-', '-/-', '₹1.10 L-1.35 L', '-/-', '-/-', '49 Courses', 'Amity JEE\n                                                 ,                                                                                                 CAT', '₹1.96 L-20.95 L', 'NAAC-A', '9 Courses']}

# %%
#converting dictionary into a dataframe
model=pd.DataFrame(college_data)
model.to_csv("colleges_up_data.csv")
model
# Out:
#                                         college_names  \
# 0                                          IIT Kanpur
# 1                                                 BHU
# 2                                                 AMU
# 3                                  IIT Varanasi (BHU)
# 4                                       Vignan Online
# 5                              Amity University Noida
# 6                                                KGMU
# 7                                Banasthali Vidyapith
# 8                                     MNNIT Allahabad
# 9                                      IIIT Allahabad
# 10                            Amity University, Noida
# 11                                          IMS Noida
# 12                                          Galgotias
# 13                            IMS Engineering College
# 14  Shri Ram Murti Smarak College of Engineering a...
# 15                                          ABS Noida
# 16                                               HBTU
# 17                                         IIIT Delhi
# 18               Institute of Management Studies, BHU
# 19             Jaipuria Institute of Management Noida
# 20                                        PSIT Kanpur
# 21                                      ITS Ghaziabad
# 22  Sri Ram Murti Smarak International Business Sc...
# 23                         Doon Business School (DBS)
# 24                                     GLA University
# 25                                        IIM Lucknow
# 26  Faculty of Engineering, Dayalbagh Educational ...
# 27           Jaipuria Institute of Management Lucknow
#
#                                        college_cities  \
# 0      Kanpur, Uttar Pradesh\nPublic\n4.4 \n # 5 NIRF
# 1   Varanasi, Uttar Pradesh\nPublic\n4.0 \n # 11 NIRF
# 2    Aligarh, Uttar Pradesh\nPublic\n3.3 \n # 16 NIRF
# 3   Varanasi, Uttar Pradesh\nPublic\n3.4 \n # 30 NIRF
# 4                              Guntur, Andhra Pradesh
# 5     Noida, Uttar Pradesh\nPrivate\n3.7 \n # 49 NIRF
# 6    Lucknow, Uttar Pradesh\nPublic\n4.1 \n # 88 NIRF
# 7                  Lucknow, Uttar Pradesh\nPrivate\n3
# 8               Allahabad, Uttar Pradesh\nPublic\n3.8
# 9               Allahabad, Uttar Pradesh\nPublic\n4.0
# 10         Greater Noida, Uttar Pradesh\nPrivate\n4.4
# 11                 Noida, Uttar Pradesh\nPrivate\n3.3
# 12                 Noida, Uttar Pradesh\nPrivate\n2.4
# 13             Ghaziabad, Uttar Pradesh\nPrivate\n3.7
# 14              Bareilly, Uttar Pradesh\nPrivate\n2.9
# 15                 Noida, Uttar Pradesh\nPrivate\n4.0
# 16                 Kanpur, Uttar Pradesh\nPublic\n3.3
# 17                Amroha, Uttar Pradesh\nPrivate\n4.3
# 18               Varanasi, Uttar Pradesh\nPublic\n4.0
# 19                 Noida, Uttar Pradesh\nPrivate\n3.7
# 20                Kanpur, Uttar Pradesh\nPrivate\n4.4
# 21             Ghaziabad, Uttar Pradesh\nPrivate\n3.5
# 22                      Unnao, Uttar Pradesh\nPrivate
# 23                Kanpur, Uttar Pradesh\nPrivate\n3.4
# 24               Mathura, Uttar Pradesh\nPrivate\n3.2
# 25                Lucknow, Uttar Pradesh\nPublic\n4.3
# 26                  Agra, Uttar Pradesh\nPrivate\n3.9
# 27               Lucknow, Uttar Pradesh\nPrivate\n3.9
#
#                                          college_fees
# 0                                           7 Courses
# 1   CAT\n                                         ...
# 2                                          ₹12 K-10 L
# 3                                                NIRF
# 4                                          48 Courses
# 5   BHU PET\n                                     ...
# 6                                        ₹500 -1.20 L
# 7                                                NAAC
# 8                                          32 Courses
# 9   NATA\n                                        ...
# 10                                      ₹15 K-13.47 L
# 11  NAAC                                          ...
# 12                                          7 Courses
# 13                                           JEE Main
# 14                                          ₹40 K-4 L
# 15                                                -/-
# 16                                                -/-
# 17                                          3 Courses
# 18                                                -/-
# 19                                                -/-
# 20                                     ₹1.10 L-1.35 L
# 21                                                -/-
# 22                                                -/-
# 23                                         49 Courses
# 24  Amity JEE\n                                   ...
# 25                                    ₹1.96 L-20.95 L
# 26                                             NAAC-A
# 27                                          9 Courses
