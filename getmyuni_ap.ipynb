# %%
import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd
#import pandas inorder to create dataframes

# %%
url="https://www.carwale.com"

# %%
r=requests.get("https://www.carwale.com")

# %%
soup=BeautifulSoup(r.content,'html.parser')
soup
# Out:
# Not Found

# %%
names=soup.find_all('h2',class_='college__name')
city=soup.find_all('div',class_='detail__list__mobile')
fees=soup.find_all('span',class_='highlight__value')

# %%
college_names = []
college_cities = []
college_fees = []

# %%
for name, city, fee in zip(names, city, fees):
    college_names.append(name.text.strip())
    college_cities.append(city.text.strip())
    college_fees.append(fee.text.strip())

# %%
college_data = {'college_names':college_names, 'college_cities':college_cities, 'college_fees':college_fees}
print(college_data)
# Out:
# {'college_names': ['Andhra University', 'KL University', 'Sri Venkateswara University (SVU)', 'Aditya Engineering College', 'Presidency University', 'GITAM', 'GPREC', 'CBIT Hyderabad', 'Andhra University College of Engineering, Visakhapatnam', 'GITAM Institute of Management, Visakhapatnam', 'Vignan Online', "St Ann's College for Women", 'Bapatla Engineering College, Bapatla Education Society', 'VRSEC', 'Gayatri Vidya Parishad College of Engineering', 'Dayananda Sagar College of Architecture', 'Shri Vishnu Engineering College for Women', 'Madanapalle Institute of Technology and Science', 'Sri Vasavi Engineering College', 'IIT Tirupati', 'Raghu Engineering College', 'SPA Vijayawada', 'Indira Priyadarshini Law College', 'Dr. Y.S.R. Horticultural University', 'Vasireddy Venkatadri Institute of Technology', 'Aditya Institute of Technology and Management', 'KPR Institute of Engineering and Technology', 'G Pullaiah College of Engineering and Technology', 'Aizza College of Engineering and Technology', 'Rajeev Gandhi Memorial College of Engineering and Technology'], 'college_cities': ['Visakhapatnam, Andhra Pradesh\nPublic\n3.6 \n # 41 NIRF', 'Guntur, Andhra Pradesh\nPrivate\n3.5 \n # 40 NIRF', 'Tirupati, Andhra Pradesh\nPublic\n3.5', 'East Godavari, Andhra Pradesh\nPrivate\n3.7', 'Bangalore, Karnataka\nPrivate\n3.9', 'Visakhapatnam, Andhra Pradesh\nPrivate\n3.8', 'Kurnool, Andhra Pradesh\nPrivate\n3.9', 'Kadapa, Andhra Pradesh\nPrivate\n3.8', 'Tadepalligudem, Andhra Pradesh\nPublic\n3.6', 'Visakhapatnam, Andhra Pradesh\nPrivate\n3.1', 'Guntur, Andhra Pradesh', 'Visakhapatnam, Andhra Pradesh\nPrivate\n3.8', 'Guntur, Andhra Pradesh\nAutonomous/Private\n3.7', 'Vijayawada, Andhra Pradesh\nPrivate\n3.9', 'Visakhapatnam, Andhra Pradesh\nPrivate\n3.7', 'Vijayawada, Andhra Pradesh\nPrivate', 'Bhimavaram, Andhra Pradesh\nPrivate\n4.2', 'Madanapalle, Andhra Pradesh\nPrivate\n3.5', 'Tadepalligudem, Andhra Pradesh\nAutonomous/Private\n3.3', 'Tirupati, Andhra Pradesh\nAutonomous\n4.3', 'Visakhapatnam, Andhra Pradesh\nPrivate\n3.1', 'Vijayawada, Andhra Pradesh\nPublic\n3.9', 'Prakasam, Andhra Pradesh\nPrivate', 'Tadepalligudem, Andhra Pradesh\nPublic', 'Guntur, Andhra Pradesh\nPrivate\n3.6', 'Srikakulam, Andhra Pradesh\nPrivate\n3.0', 'Eluru, Andhra Pradesh\nPrivate\n2.9', 'Kurnool, Andhra Pradesh\nPrivate\n4', 'Adilabad, Andhra Pradesh\nPrivate', 'Nandyala, Andhra Pradesh\nPrivate\n3.2'], 'college_fees': ['34 Courses', 'AP PGECET', '₹16 K-14.44 L', 'NAAC', '23 Courses', 'AP EAMCET\n                                                 ,                                                                                                 GATE', '₹1.40 L-15.60 L', 'NAAC-A', '18 Courses', 'AP EAMCET', '₹8 K-2.71 L', '-/-', '-/-', '5 Courses', '-/-', '-/-', '₹54 K-2.01 L', 'NAAC-A                                                 ,                                                                                                  NBA                                                                                                \n                                        +1                                            \n                                                                                                                                                                                                         NIRF', '10 Courses', 'ATMA\n\n                                                                                                         ,                                                                                                                                                                                                 CAT', '₹1 L-3.13 L', 'NAAC-A', '18 Courses', 'GITAM GAT', '₹96 K-14.50 L', 'NAAC', '3 Courses', 'AP EAMCET\n                                                 ,                                                                                                 AP PGECET', '₹1.14 L-3.20 L', 'NAAC                                                 ...

# %%
model=pd.DataFrame(data=college_data)
model.to_csv("colleges_ap_data.csv")
model
# Out:
#                                         college_names  \
# 0                                   Andhra University
# 1                                       KL University
# 2                   Sri Venkateswara University (SVU)
# 3                          Aditya Engineering College
# 4                               Presidency University
# 5                                               GITAM
# 6                                               GPREC
# 7                                      CBIT Hyderabad
# 8   Andhra University College of Engineering, Visa...
# 9        GITAM Institute of Management, Visakhapatnam
# 10                                      Vignan Online
# 11                         St Ann's College for Women
# 12  Bapatla Engineering College, Bapatla Education...
# 13                                              VRSEC
# 14      Gayatri Vidya Parishad College of Engineering
# 15            Dayananda Sagar College of Architecture
# 16          Shri Vishnu Engineering College for Women
# 17    Madanapalle Institute of Technology and Science
# 18                     Sri Vasavi Engineering College
# 19                                       IIT Tirupati
# 20                          Raghu Engineering College
# 21                                     SPA Vijayawada
# 22                   Indira Priyadarshini Law College
# 23                Dr. Y.S.R. Horticultural University
# 24       Vasireddy Venkatadri Institute of Technology
# 25      Aditya Institute of Technology and Management
# 26        KPR Institute of Engineering and Technology
# 27   G Pullaiah College of Engineering and Technology
# 28        Aizza College of Engineering and Technology
# 29  Rajeev Gandhi Memorial College of Engineering ...
#
#                                        college_cities  \
# 0   Visakhapatnam, Andhra Pradesh\nPublic\n3.6 \n ...
# 1   Guntur, Andhra Pradesh\nPrivate\n3.5 \n # 40 NIRF
# 2               Tirupati, Andhra Pradesh\nPublic\n3.5
# 3         East Godavari, Andhra Pradesh\nPrivate\n3.7
# 4                  Bangalore, Karnataka\nPrivate\n3.9
# 5         Visakhapatnam, Andhra Pradesh\nPrivate\n3.8
# 6               Kurnool, Andhra Pradesh\nPrivate\n3.9
# 7                Kadapa, Andhra Pradesh\nPrivate\n3.8
# 8         Tadepalligudem, Andhra Pradesh\nPublic\n3.6
# 9         Visakhapatnam, Andhra Pradesh\nPrivate\n3.1
# 10                             Guntur, Andhra Pradesh
# 11        Visakhapatnam, Andhra Pradesh\nPrivate\n3.8
# 12    Guntur, Andhra Pradesh\nAutonomous/Private\n3.7
# 13           Vijayawada, Andhra Pradesh\nPrivate\n3.9
# 14        Visakhapatnam, Andhra Pradesh\nPrivate\n3.7
# 15                Vijayawada, Andhra Pradesh\nPrivate
# 16           Bhimavaram, Andhra Pradesh\nPrivate\n4.2
# 17          Madanapalle, Andhra Pradesh\nPrivate\n3.5
# 18  Tadepalligudem, Andhra Pradesh\nAutonomous/Pri...
# 19          Tirupati, Andhra Pradesh\nAutonomous\n4.3
# 20        Visakhapatnam, Andhra Pradesh\nPrivate\n3.1
# 21            Vijayawada, Andhra Pradesh\nPublic\n3.9
# 22                  Prakasam, Andhra Pradesh\nPrivate
# 23             Tadepalligudem, Andhra Pradesh\nPublic
# 24               Guntur, Andhra Pradesh\nPrivate\n3.6
# 25           Srikakulam, Andhra Pradesh\nPrivate\n3.0
# 26                Eluru, Andhra Pradesh\nPrivate\n2.9
# 27                Kurnool, Andhra Pradesh\nPrivate\n4
# 28                  Adilabad, Andhra Pradesh\nPrivate
# 29             Nandyala, Andhra Pradesh\nPrivate\n3.2
#
#                                          college_fees
# 0                                          34 Courses
# 1                                           AP PGECET
# 2                                       ₹16 K-14.44 L
# 3                                                NAAC
# 4                                          23 Courses
# 5   AP EAMCET\n                                   ...
# 6                                     ₹1.40 L-15.60 L
# 7                                              NAAC-A
# 8                                          18 Courses
# 9                                           AP EAMCET
# 10                                        ₹8 K-2.71 L
# 11                                                -/-
# 12                                                -/-
# 13                                          5 Courses
# 14                                                -/-
# 15                                                -/-
# 16                                       ₹54 K-2.01 L
# 17  NAAC-A                                        ...
# 18                                         10 Courses
# 19  ATMA\n\n                                      ...
# 20                                        ₹1 L-3.13 L
# 21                                             NAAC-A
# 22                                         18 Courses
# 23                                          GITAM GAT
# 24                                      ₹96 K-14.50 L
# 25                                               NAAC
# 26                                          3 Courses
# 27  AP EAMCET\n                                   ...
# 28                                     ₹1.14 L-3.20 L
# 29  NAAC                                          ...
