# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import csv

# %%
url = "https://www.getmyuni.com/all-colleges/tamil-nadu"

# %%
r = requests.get(url)

# %%
soup = BeautifulSoup(r.content,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <!-- <meta http-equiv="Content-Type" content="text/html"> -->
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=0" name="viewport">
# <meta content="#545ebd" name="theme-color"/>
# <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
# <!-- <link rel="dns-prefetch" href="//cdnjs.cloudflare.com/"> -->
# <link crossorigin="" href="https://www.googletagmanager.com/" rel="preconnect"/>
# <link href="//www.google-analytics.com" rel="preconnect">
# <!-- <link rel="preconnect" href="https://cdnjs.cloudflare.com/" /> -->
# <link href="https://securepubads.g.doubleclick.net" rel="preconnect"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch">
# <link href="https://securepubads.g.doubleclick.net" rel="dns-prefetch"/>
# <!-- <link rel="dns-prefetch" crossorigin href="https://fonts.googleapis.com/" /> -->
# <link href="https://www.getmyuni.com/favicon.png" rel="shortcut icon" type="image/png">
# <link href="https://www.getmyuni.com/favicon.png" rel="icon" type="image/x-icon"/>
# <link as="font" crossorigin="" href="/yas/fonts/woff/roboto-regular-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/yas/fonts/woff/roboto-medium-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/yas/fonts/woff/roboto-bold-webfont.woff2" rel="preload" type="font/woff2"/>
# <link href="/yas/css/version2/jquery-ui.min.css" media="print" onload="this.media='all'" rel="stylesheet"/>
# <title>
#         Top Colleges in Tamil Nadu 2024: Ranking, Courses, Fees &amp; Placements    </title>
# <meta content="Find Top Colleges in Tamil Nadu based on  ranking with details on courses, fees, placements, admission, reviews, cut off, and latest news." name="description"/>
# <meta content="website" property="og:type"/>
# <meta content="Top Colleges in Tamil Nadu 2024: Ranking, Courses, Fees &amp; Placements" property="og:title"/>
# <meta content="https://www.getmyuni.com/all-colleges/tamil-nadu" property="og:url"/>
# <meta content="Getmyuni" property="og:site_name"/>
# <meta content="Find Top Colleges in Tamil Nadu based on  ranking with details on courses, fees, placements, admission, reviews, cut off, and latest news." property="og:description"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Getmyuni" property="twitter:site"/>
# <meta content="@getmyuniedu" property="twitter:creator"/>
# <meta content="https://www.getmyuni.com/all-colleges/tamil-nadu" property="twitter:url"/>
# <meta content="Top Colleges in Tamil Nadu 2024: Ranking, Courses, Fees &amp; Placements" property="twitter:title"/>
# <meta content="Find Top Colleges in Tamil Nadu based on  ranking with details on courses, fees, placements, admission, reviews, cut off, and latest news." property="twitter:description"/>
# <meta content="https://media.getmyuni.com/yas/images/banner.png" property="og:image"/>
# <meta content="https://media.getmyuni.com/yas/images/banner.png" property="twitter:image"/>
# <link href="https://www.getmyuni.com/all-colleges/tamil-nadu" rel="canonical"/>
# <link href="/yas/css/version2/min/style.css?v=1729774232" rel="stylesheet"/>
# <link href="/yas/css/version2/min/header.css?v=1729774232" rel="stylesheet"/>
# <link href="/yas/css/version2/college-landing-new.css?v=1729071435" rel="stylesheet"/>
# <link href="/yas/css/version2/college-compare-panel.css?v=1729071435" rel="stylesheet"/>
# <style>.blueBgDiv.mobileOnly { display: none!important; }</style> <script>
#         var gmu = {};
#         gmu.config = {
#             showLeadForm: 'true',
#             entity: 'college-listing',
#             product_mapping_entity: 'false',
#             product_mapping_entity_id: 0,
#             pageName: '',
#             entity_id: 0,
#             college_course_count: '',
#             course_id: '',
#             program_id: '',
#             entity_name: "College-Listing-Page",
#             entity_slug: '',
#             board_level: '',
#             display_name: '',
#             pageName: '',
#             page_category: '',
#             entity_type: 'college-listing',
#             entity_subtype: 'state',
#             entity_city: '',
#             interested_location: '',
#             interested_location_state: '',
#             cta_location: 'auto-popup',
#             show_lead_form: false,
#             utm_source: '',
#             utm_campaign: '',
#             utm_medium: '',
#             sponsor_params: {"state":"tamil-nadu","stream":null,"course":null,"specialization":null},
#             courseChartData: [],
#             isLoggedIn: false,
#             previous_url: '',
#             page_url: 'https://www.getmyuni.com/all-colleges/tamil-nadu',
#             isMobile: '',
#             mapData: [],
#             statusCode: 200,
#             currentLocation: 'https://www.getmyuni.com/all-colleges/tamil-nadu',
#             dynamicCta: {"cta_position_0":{"lead_form_title":"Sign-up to Download","lead_form_description":", ","cta_text":"<span class=\"spriteIcon whiteDownloadIcon redDownloadIcon\"><\/span> Brochure","cta_title":"","page_event":null,"page_link":null,"web":"colleges_listing__card_left_cta_web","wap":"colleges_listing__card_left_cta_wap","template":2},"cta_position_1":{"lead_form_title":"Sign-up to Apply","lead_form_description":", ","cta_text":"Apply Now","cta_title":"","page_event":null,"page_link":null,"web":"colleges_listing__card_right_cta_web","wap":"colleges_listing__card_right_cta_wap","template":2},"cta_position_2":{"lead_form_title":"Sign-up to Download","lead_form_description":", ","cta_text":"<span class=\"spriteIcon whiteDownloadIcon redDownloadIcon\"><\/span> Brochure","cta_title":"","page_event":null,"page_link":null,"web":"colleges_listing__card_left_cta1_web","wap":"colleges_listing__card_left_cta1_wap","template":2},"cta_position_3":{"lead_form_title":"Register to Shortlist","lead_form_description":"Register to Shortlist","cta_text":"Shortlist","cta_title":"","page_event":null,"page_link":null,"web":"colleges_listing__card_right_cta1_web","wap":"colleges_listing__card_right_cta1_wap","template":2},"cta_position_4":{"lead_form_title":"Get Counselling from experts, free of cost !","lead_form_description":"","cta_text":"Talk to Experts","cta_title":"","page_event":null,"page_link":null,"web":"colleges_listing_single_top_cta_web","wap":"colleges_listing_single_top_cta_wap","template":2}},
#             csrf: 'HPt_5VcJQ-8vYqIvZpB6gMKdfi4LV2F-4MjQ-WRvWJd1rBC0HX4cmGQOxE1e5hntkehPVFg_FDWFgbSxNQgy_w==',
#             language: 'en',
#             domainUrl: 'https://www.getmyuni.com/',
#             prodEvn : 'prod',
#             careerChartData: [],
#         };
#
#         var googletag = googletag || {};
#         googletag.cmd = googletag.cmd || [];
#         // GPT slots
#         var gptAdSlots = [];
#         googletag.cmd.push(function() {
#             gptAdSlots[0] = googletag.defineSlot('/21840540389/gmu_new_listing_page_web_390x90_mtf_1', [390,90], 'div-gpt-ad-1614408539431-0').addService(googletag.pubads());
# gptAdSlots[1] = googletag.defineSlot('/21840540389/gmu_new_listing_page_web_390x90_mtf_1', [390,90], 'div-gpt-ad-1614408539431-1').addService(googletag.pubads());
# gptAdSlots[2] = googletag.defineSlot('/21840540389/gmu_new_listing_page_web_390x90_mtf_1', [390,90], 'div-gpt-ad-1614408539431-2').addService(googletag.pubads());
# gptAdSlots[3] = googletag.defineSlot('/21840540389/gmu_new_listing_page_web_250x200_mtf_1', [250,200], 'div-gpt-ad-1614408539431-3').addService(googletag.pubads());
# gptAdSlots[4] = googletag.defineSlot('/21840540389/gmu_new_listing_page_web_250x200_mtf_1', [250,200], 'div-gpt-ad-1614408539431-4').addService(googletag.pubads());
# gptAdSlots[5] = googletag.defineSlot('/21840540389/gmu_new_listing_page_web_390x90_mtf_1', [390,90], 'div-gpt-ad-1614408539431-5').addService(googletag.pubads());
#
#             // Configure SRA
#             googletag.pubads().enableSingleRequest();
#             googletag.pubads().enableLazyLoad();
#             // Start ad fetching
#             googletag.enableServices();
#         });
#     </script>
# <script id="_webengage_script_tag" type="text/javascript">
#         var webengage;
#         ! function(w, e, b, n, g) {
#             function o(e, t) {
#                 e[t[t.length - 1]] = function() {
#                     r.__queue.push([t.join("."), arguments])
#                 }
#             }
#             var i, s, r = w[b],
#                 z = " ",
#                 l = "init options track screen onReady".split(z),
#                 a = "feedback survey notification".split(z),
#                 c = "options render clear abort".split(z),
#                 p = "Open Close Submit Complete View Click".split(z),
#                 u = "identify login logout setAttribute".split(z);
#             if (!r || !r.__v) {
#                 for (w[b] = r = {
#                         __queue: [],
#                         __v: "6.0",
#                         user: {}
#                     }, i = 0; i < l.length; i++) o(r, [l[i]]);
#                 for (i = 0; i < a.length; i++) {
#                     for (r[a[i]] = {}, s = 0; s < c.length; s++) o(r[a[i]], [a[i], c[s]]);
#                     for (s = 0; s < p.length; s++) o(r[a[i]], [a[i], "on" + p[s]])
#                 }
#                 for (i = 0; i < u.length; i++) o(r.user, ["user", u[i]]);
#                 setTimeout(function() {
#                     var f = e.createElement("script"),
#                         d = e.getElementById("_webengage_script_tag");
#                     f.type = "text/javascript",
#                         f.async = !0,
#                         f.src = ("https:" == e.location.protocol ? "https://widgets.in.webengage.com" : "http://widgets.in.webengage.com") + "/js/webengage-min-v-6.0.js",
#                         d.parentNode.insertBefore(f, d);
#                 }, 10000)
#             }
#         }(window, document, "webengage");
#         webengage.init('in~d3a49c51');
#         webengage.onReady(function() {
#             webengage.notification.onOpen(function(data) {
#                 var a = document.getElementById('webklipper-publisher-widget-container-notification-frame');
#                 var layoutId = a.dataset.notificationLayoutId;
#                 if (layoutId == '~483819h') {
#                     a.style.left = 'auto';
#                     a.style.top = 'auto';
#                     a.style.transform = 'none';
#                     a.style.zIndex = 1;
#                     var _stickyBtn = document.getElementsByClassName("getSupport").length ? document.getElementsByClassName("getSupport")[0] : null;
#                     a.style.bottom = '0px';
#                     if (_stickyBtn) {
#                         a.style.bottom = _stickyBtn.getBoundingClientRect().height + 'px';
#                     }
#                     var throttle = function(callback, delay) {
#                         var throttleTimeout = null;
#                         var storedEvent = null;
#
#                         var throttledEventHandler = function(event) {
#                             storedEvent = event;
#
#                             var shouldHandleEvent = !throttleTimeout;
#
#                             if (shouldHandleEvent) {
#                                 callback(storedEvent);
#
#                                 storedEvent = null;
#
#                                 throttleTimeout = setTimeout(function() {
#                                     throttleTimeout = null;
#
#                                     if (storedEvent) {
#                                         throttledEventHandler(storedEvent);
#                                     }
#                                 }, delay);
#                             }
#                         };
#
#                         return throttledEventHandler;
#                     };
#                     var scrollThrottle = throttle(function() {
#                         if (_stickyBtn) {
#                             a.style.bottom = _stickyBtn.getBoundingClientRect().height + 'px';
#                         }
#                     }, 1000);
#                     document.addEventListener("scroll", scrollThrottle);
#                 }
#             });
#         });
#     </script>
# <!-- Google Tag Manager --> <script data-cfasync="false">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.defer=true;j.src= 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f); })(window,document,'script','dataLayer','GTM-MMVP8S');</script> <!-- End Google Tag Manager -->
# </link></link></link></meta></head>
# <!-- <body> -->
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MMVP8S" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>
#         (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-MMVP8S');
#     </script>
# <header class="page-header" id="primary-js-nav">
# <div class="topHeader">
# <div class="container">
# <div class="row">
# <div class="mobileOnly">
# <p class="spriteIcon hambergerIcon"></p>
# </div>
# <a class="spriteIcon headerLogo" href="/" title="Getmyuni"></a>
# <ul>
# <li><a href="https://www.getmyuni.com/all-colleges" title="Top Colleges in India">Top Colleges</a></li>
# <li><a href="https://www.getmyuni.com/courses" title="Courses in India">Top Courses</a></li>
# <li><a href="https://www.getmyuni.com/exams" title="Entrance Exams in India">Entrance Exams</a></li>
# <li><a href="https://www.getmyuni.com/boards" title="Education Boards in India">Boards</a></li>
# <li><a href="https://www.getmyuni.com/college/admissions" title="College Admission in India">Admission 2024</a></li>
# <li><a href="https://news.getmyuni.com/" title="News">News</a></li>
# <!-- <li><a href="javascript:;">Study Abroad</a></li> -->
# <!-- <li class="sa_dropdown">
#                         <a class="" href="javascript:;">Study Abroad<span class="spriteIcon whiteCaretIcon"></span></a>
#                         <ul class="study-abroad-options study-abroad">
#                             <li><a href="https://www.getmyuni.com/canada" title="Study in Canada">Study in Canada</a></li>
#                             <li><a href="https://www.getmyuni.com/uk" title="Study in UK">Study in UK</a></li>
#                             <li><a href="https://www.getmyuni.com/usa" title="Study in USA">Study in USA</a></li>
#                             <li><a href="https://www.getmyuni.com/australia" title="Study in Australia">Study in Australia</a></li>
#                             <li><a href="https://www.getmyuni.com/germany" title="Study in Germany">Study in Germany</a></li>
#                             <li><a href="https://ieltsmaterial.com/" target="_blank">IELTS Material</a></li>
#                         </ul>
#                     </li> -->
# <li class="sa_dropdown">
# <a class="" href="javascript:;">More<span class="spriteIcon whiteCaretIcon"></span></a>
# <ul class="study-abroad-options study-abroad">
# <!-- <li class="srcSpanIcon"></li> -->
# <!-- <div class="row">
#                                     <div class="col-md-12"> -->
# <!-- <ul> -->
# <li><a href="https://www.getmyuni.com/articles" title="Articles">Articles</a></li>
# <!-- <li><a title="NCERT" href="https://www.getmyuni.com/ncert">NCERT</a></li> -->
# <!-- <li><a title="Compare Colleges" class="submenulist" href="https://www.getmyuni.com/college-compare">Compare Colleges</a> -->
# <li><a class="submenulist" href="https://www.getmyuni.com/scholarships" title="Scholarships">Scholarships</a></li>
# <!-- <li><a title="Olympiads" class="submenulist" href="https://www.getmyuni.com/olympiad">Olympiads</a></li> -->
# <!-- <li><a title="Sarkari Exam" class="submenulist" href="https://www.getmyuni.com/sarkari-exam/">Sarkari Exam</a></li> -->
# <!-- <li><a title="Visual Stories" class="submenulist" href="https://webstories.getmyuni.com/">Visual Stories</a></li> -->
# <!-- <li><a title="QnA" href="https://www.getmyuni.com/q-n-a">QnA</a></li> -->
# <li><a class="submenulist" href="https://www.getmyuni.com/college-compare" title="College Compare">College Compare</a></li>
# <!-- </ul> -->
# <!-- </div>
#                                 </div> -->
# </ul>
# </li>
# <!-- <li><a href="https://www.getmyuni.com/college/reviews" title="College Reviews">Reviews</a></li> -->
# <li><a class="spriteIcon searchIcon" href="javascript:;"></a></li>
# <li><a class="writeReview" href="https://www.getmyuni.com/review/create" title="Write a Review">Write a review</a></li>
# <!-- <a class="registerNew" id="mobileRegisterNew" href="/site/login">Login/ Register</a> -->
# <li id="registerNew"><a class="writeReview" href="/site/login">Login/ Register</a></li>
# <li id="loggedInUser"></li>
# <!-- <li><a class="register" href="https://www.getmyuni.com/login" title="Login / Register">Login / Register</a></li> -->
# </ul>
# <div class="mobileOnly">
# <a class="spriteIcon searchIcon"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="headerMegaMenu" id="secondaryHeader-web"></div>
# <div class="advanceSearch">
# <div class="searchWrap active">
# <a class="close-layer desktopOnly"></a>
# <div class="searchContent">
# <div class="seachInner">
# <div class="sugstrbox">
# <div class="inputDiv">
# <span class="mobileOnly leftArrow">
# <i class="spriteIcon backIcon"></i>
# </span>
# <input autocomplete="off" class="form-control seachInput" id="seachInput" placeholder="Search Colleges, Courses, Exams" tabindex="1" type="text" value=""/>
# <div class="close-icone inputClose">
# <span class="close-span"></span>
# </div>
# <p id="letterCount"></p>
# </div>
# <button class="primaryBtn desktopOnly" type="submit">Search</button>
# </div>
# <div class="showsuggestorBox"></div>
# <div class="rctSearchWrap" id="showSearchDiv"></div>
# </div>
# </div>
# </div>
# </div> </header>
# <script type="application/ld+json">{"@context":"http:\/\/schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@type":"WebPage","@id":"https:\/\/www.getmyuni.com","name":"Home"}},{"@type":"ListItem","position":2,"item":{"@type":"WebPage","@id":"https:\/\/www.getmyuni.com\/all-colleges","name":"Colleges"}},{"@type":"ListItem","position":3,"item":{"@type":"WebPage","@id":"https:\/\/www.getmyuni.com\/all-colleges\/tamil-nadu","name":"Top Colleges in Tamil Nadu 2024"}}]}</script> <nav class="breadcrumbDiv news">
# <div class="container">
# <ul class="breadcrumb"><li><a href="/" title="Home">Home</a></li>
# <li><a href="/all-colleges" title="Colleges">Colleges</a></li>
# <li class="active">Top Colleges in Tamil Nadu 2024</li>
# </ul> </div>
# </nav>
# <div class="blueBgDiv mobileOnly">
# <!-- do not delete this -->
# </div>
# <div class="container">
# <div class="college__Landing__New">
# <div class="container top__ads">
# <div class="row">
# <div class="col-md-4">
# <div class="lazy-ad" data-slot="0" id="div-gpt-ad-1614408539431-0" style="height:90px"><script>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1614408539431-0'); });</script></div> </div>
# <div class="col-md-4 desktopOnly">
# <div class="lazy-ad" data-slot="1" id="div-gpt-ad-1614408539431-1" style="height:90px"><script>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1614408539431-1'); });</script></div> </div>
# <div class="col-md-4 desktopOnly">
# <div class="lazy-ad" data-slot="2" id="div-gpt-ad-1614408539431-2" style="height:90px"><script>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1614408539431-2'); });</script></div> </div>
# </div>
# </div>
# <div class="college__Landing__Hero__Section1">
# <div class="college__Landing__Hero__Section pageData pageInfo">
# <h1 class="college__Landing__Hero__Section__Heading">Top Colleges in Tamil Nadu 2024</h1>
# </div> </div>
# <!--aside>
#                                                         <div class="horizontalRectangle">
#                                                                 <div class="appendAdDiv xs-h100" style="background:#EAEAEA;">
#                                                                                                                                                                                                                                                                 </div>
#                                                         </div>
#                                                         </aside-->
# </div>
# <div class="row">
# <div class="all-college-ajax col-md-3 lg-pr-0" style="min-height: 100vh;">
# </div>
# <div class="col-md-6 mobile__white__bg">
# <div class="filter__selected__container">
# <div class="filterDiv" id="selectedFilters">
# <button class="filter__selected" data-attr="state" id="tamil-nadu">
#                             Tamil Nadu<i class="spriteIcon small__close__icon remove-college-filter"></i></button>
# </div>
# <div class="mobile__clear__filter">
# <span class="clearAll" id="clearAllClg">Clear All</span> </div>
# </div>
# <div class="sort__row__container">
# <h3 class="filtered__college_count">Showing 1296 Colleges </h3>
# <div class="sortBy__select2__container desktopOnly">
# <span>Sort By:</span>
# <select id="college-sort" name="college-sort">
# <option value="position">Popularity</option>
# <option selected="" value="rank">Ranking</option>
# <option value="highest_fee">Highest Fees</option>
# <option value="lowest_fee">Lowest Fees</option>
# </select> </div>
# </div>
# <div class="searchBar">
# <input autocomplete="off" class="search-autocomplete1 search-listing" id="autoComplete" placeholder="Search for Colleges" tabindex="1" type="text"/>
# <i class="spriteIcon small__close__icon search-remove"></i>
# <div class="selection"></div>
# </div>
# <div class="filtered__colleges__list">
# <div class="searchedcollegeList">
# <div class="college__card__new" id="search-582">
# <div class="card__header__row">
# <div class="college__detail__grid">
# <img alt="" class="college__image" height="56" loading="" onclick="gmu.url.goto('/college/indian-institute-of-technology-iit-chennai')" src="https://media.getmyuni.com/azure/college-image/small/indian-institute-of-technology-iit-chennai.jpg" width="56"/>
# <span class="list__style college__rank mobileOnly"> # 1 NIRF  </span>
# <div class="college__detail__row">
# <h2 class="college__name"><a data-hide="582" href="/college/indian-institute-of-technology-iit-chennai" title="IIT Madras">IIT Madras</a></h2>
# <div class="detail__list__mobile">
# <span class="list__style college__location">Chennai, Tamil Nadu</span>
# <span class="list__style college__affiliation">Public</span>
# <a class="list__style list__style__rating" href="/college/indian-institute-of-technology-iit-chennai/reviews" target="_blank" title="IIT Madras - Indian Institute of Technology Reviews"><span class="list__style college__rating"><span class="spriteIcon__2 review__star__icon"></span>4.3</span> </a>
# <span class="list__style college__rank desktopOnly"> # 1 NIRF  </span> <div class="like__compare__grid mobileOnly">
# <!--span
#                                                                                                         class="heart__icon spriteIcon__2"></span-->
# <span class="compare__icon spriteIcon__2 compareIcon"></span>
# </div>
# </div>
# </div>
# </div>
# <div class="like__compare__grid desktopOnly">
# <!--span class="heart__icon spriteIcon__2"></span-->
# <span class="compare__icon spriteIcon__2 compareIcon"></span>
# </div>
# </div>
# <div class="highlight__cta__row">
# <div class="highlights__grid">
# <div class="highlight__div">
# <span class="highlight__name">Courses
#                                 Offered</span>
# <span class="highlight__value">
# <p> <a href=" https://www.getmyuni.com/college/indian-institute-of-technology-iit-chennai-courses-fees" title="IIT Madras Courses &amp; Fee Details">
#                                                 7 Courses
#                                             </a>
# </p>
# </span>
# </div>
# <div class="highlight__div exam__accepted__div">
# <p class="highlight__name">Exam
#                                 Accepted</p>
# <span class="highlight__value">
# <a href="/exams/cat" target="_blank">CAT</a>
#                                                  ,                                                                                                 <a href="/exams/iit-jam" target="_blank">IIT JAM</a>
# </span>
# <div class="hover__tooltop">+1                                <span class="hover__card">
# <a href="/exams/jee-advanced" target="_blank">JEE Advanced</a>
# </span>
# </div>
# </div>
# <div class="desktopOnly"></div>
# <div class="highlight__div">
# <span class="highlight__name">Tuition
#                                 Fees Range</span>
# <span class="highlight__value">
#                                 ₹6 K-8 L                            </span>
# </div>
# <div class="highlight__div">
# <span class="highlight__name">Accreditation</span>
# <span class="highlight__value">
# <span class="highlight__value"> -/- </span>
# <!--span class="highlight__value"> //!empty($model['median_salary']) ? '₹' . CollegeHelper::feesFormat(floor($model['median_salary'])) : '-/-' ?></span!-->
# </span></div>
# <div class="highlight__div"></div>
# </div>
# <div class="cta__grid">
# <div class="cta__div lead-cta-college-filter-2 leadFilterData download__brochure" data-cityid="627" data-course="" data-ctalocation="colleges_listing_indian-institute-of-technology-iit-chennai_card_right_cta_web" data-description="IIT Madras, Chennai" data-entity="college" data-filter="college-listing" data-image="https://media.getmyuni.com/azure/college-image/small/indian-institute-of-technology-iit-chennai.jpg" data-lead_cta="21" data-slug="582" data-stateid="15" data-stream="" data-title="Sign-up to Apply">
# </div>
# <div class="cta__div lead-cta-college-filter-1 leadFilterData primaryBtn" data-cityid="627" data-course="" data-ctalocation="colleges_listing_indian-institute-of-technology-iit-chennai_card_left_cta_web" data-description="IIT Madras, Chennai" data-entity="college" data-filter="college-listing" data-image="https://media.getmyuni.com/azure/college-image/small/indian-institute-of-technology-iit-chennai.jpg" data-lead_cta="23" data-slug="582" data-stateid="15" data-stream="" data-title="Sign-up to Download">
# </div>
# </div>
# </div>
# </div>
# <div class="college__card__new" id="search-50">
# <div class="card__header__row">
# <div class="college__detail__grid">
# <img alt="" class="college__image" height="56" loading="" onclick="gmu.url.goto('/college/amrita-vishwa-vidyapeetham-university-coimbatore')" src="https://media.getmyuni.com/azure/college-image/small/amrita-vishwa-vidyapeetham-university-coimbatore.jpg" width="56"/>
# <span class="list__style college__rank mobileOnly"> # 18 NIRF  </span>
# <div class="college__detail__row">
# <h2 class="college__name"><a data-hide="50" href="/college/amrita-vishwa-vidyapeetham-university-coimbatore" title="Amrita Vishwa Vidyapeetham">Amrita Vishwa Vidyapeetham</a></h2>
# <div class="detail__list__mobile">
# <span class="list__style college__location">Coimbatore, Tamil Nadu</span>
# <span class="list__style college__affiliation">Private</span>
# <a class="list__style list__style__rating" href="/college/amrita-vishwa-vidyapeetham-university-coimbatore/reviews" target="_blank" title="Amrita Vishwa Vidyapeetham, Coimbatore Reviews"><span class="list__style college__rating"><span class="spriteIcon__2 review__star__icon"></span>3.9</span> </a>
# <span class="list__style college__rank desktopOnly"> # 18 NIRF  </span> <div class="like__compare__grid mobileOnly">
# <!--span
#                                                                                                         class="heart__icon spriteIcon__2"></span-->
# <span class="compare__icon spriteIcon__2 compareIcon"></span>
# </div>
# </div>
# </div>
# </div>
# <div class="like__compare__grid desktopOnly">
# <!--span class="heart__icon spriteIcon__2"></span-->
# <span class="compare__icon spriteIcon__2 compareIcon"></span>
# </div>
# </div>
# <div class="highlight__cta__row">
# <div class="highlights__grid">
# <div class="highlight__div">
# <span class="highlight__name">Courses
#                                 Offered</span>
# <span class="highlight__value">
# <p> <a href=" https://www.getmyuni.com/college/amrita-vishwa-vidyapeetham-university-coimbatore-courses-fees" title="Amrita Vishwa Vidyapeetham Courses &amp; Fee Details">
#                                                 10 Courses
#                                             </a>
# </p>
# </span>
# </div>
# <div class="highlight__div exam__accepted__div">
# <p class="highlight__name">Exam
#                                 Accepted</p>
# <span class="highlight__value">
# <a href="/exams/cat" target="_blank">CAT</a>
# </span>
# <div class="hover__tooltop"> <span class="hover__card">
# </span>
# </div>
# </div>
# <div class="desktopOnly"></div>
# <div class="highlight__div">
# <span class="highlight__name">Tuition
#                                 Fees Range</span>
# <span class="highlight__value">
#                                 ₹90 K-16.33 L                            </span>
# </div>
# <div class="highlight__div">
# <span class="highlight__name">Accreditation</span>
# <span class="highlight__value">
# <span class="highlight__value"> -/- </span>
# <!--span class="highlight__value"> //!empty($model['median_salary']) ? '₹' . CollegeHelper::feesFormat(floor($model['median_salary'])) : '-/-' ?></span!-->
# </span></div>
# <div class="highlight__div"></div>
# </div>
# <div class="cta__grid">
# <div class="cta__div lead-cta-college-filter-2 leadFilterData download__brochure" data-cityid="628" data-course="" data-ctalocation="colleges_listing_amrita-vishwa-vidyapeetham-university-coimbatore_card_right_cta_web" data-description="Amrita Vishwa Vidyapeetham, Coimbatore" data-entity="college" data-filter="college-listing" data-image="https://media.getmyuni.com/azure/college-image/small/amrita-vishwa-vidyapeetham-university-coimbatore.jpg" data-lead_cta="21" data-slug="50" data-stateid="15" data-stream="" data-title="Sign-up to Apply">
# </div>
# <div class="cta__div lead-cta-college-filter-1 leadFilterData primaryBtn" data-cityid="628" data-course="" data-ctalocation="colleges_listing_amrita-vishwa-vidyapeetham-university-coimbatore_card_left_cta_web" data-description="Amrita Vishwa Vidyapeetham, Coimbatore" data-entity="college" data-filter="college-listing" data-image="https://media.getmyuni.com/azure/college-image/small/amrita-vishwa-vidyapeetham-university-coimbatore.jpg" data-lead_cta="23" data-slug="50" data-stateid="15" data-stream="" data-title="Sign-up to Download">
# </div>
# </div>
# </div>
# </div>
# <div class="filter__by__exam hide__widget">
# <div class="heading__row">
# <h3 class="exam__row__heading">Filter By Stream</h3>
# <!--div class="view__all__exams">View All
#                     <span class="spriteIcon__2 blue__angle__icon"></span>
#             </div-->
# </div>
# <ul class="exam__list">
# <a href="https://www.getmyuni.com/engineering-colleges/tamil-nadu" style="text-decoration:none; cursor:pointer; " target="_blank"><li>Engineering (539)</li></a>
# <a href="https://www.getmyuni.com/arts-colleges/tamil-nadu" style="text-decoration:none; cursor:pointer; " target="_blank"><li>Arts (414)</li></a>
# <a href="https://www.getmyuni.com/management-colleges/tamil-nadu" style="text-decoration:none; cursor:pointer; " target="_blank"><li>Management (530)</li></a>
# <a href="https://www.getmyuni.com/science-colleges/tamil-nadu" style="text-decoration:none; cursor:pointer; " target="_blank"><li>Science (414)</li></a>
# <a href="https://www.getmyuni.com/education-colleges/tamil-nadu" style="text-decoration:none; cursor:pointer; " target="_blank"><li>Education (352)</li></a>
# <a href="https://www.getmyuni.com/commerce-colleges/tamil-nadu" style="text-decoration:none; cursor:pointer; " target="_blank"><li>Commerce (298)</li></a>
# <a href="https://www.getmyuni.com/computer-colleges/tamil-nadu" style="text-decoration:none; cursor:pointer; " target="_blank"><li>Computer (398)</li></a>
# <a href="https://www.getmyuni.com/medical-colleges/tamil-nadu" style="text-decoration:none; cursor:pointer; " target="_blank"><li>Medical (59)</li></a>
# </ul>
# </div>
# <div class="college__card__new" id="search-5445">
# <div class="card__header__row">
# <div class="college__detail__grid">
# <img alt="" class="college__image" height="56" loading="" onclick="gmu.url.goto('/college/vellore-institute-of-technology-vellore')" src="https://media.getmyuni.com/azure/college-image/small/vellore-institute-of-technology-vellore.jpg" width="56"/>
# <div class="college__detail__row">
# <h2 class="college__name"><a data-hide="5445" href="/college/vellore-institute-of-technology-vellore" title="Vellore Institute of Technology">Vellore Institute of Technology</a></h2>
# <div class="detail__list__mobile">
# <span class="list__style college__location">Vellore, Tamil Nadu</span>
# <span class="list__style college__affiliation"></span>
# <span class="list__style college__rating"><span class="spriteIcon__2 review__star__icon"></span>4.2</span>
# <div class="like__compare__grid mobileOnly">
# <!--span
#                                                                                                         class="heart__icon spriteIcon__2"></span-->
# <span class="compare__icon spriteIcon__2 compareIcon"></span>
# </div>
# </div>
# </div>
# </div>
# <div class="like__compare__grid desktopOnly">
# <!--span class="heart__icon spriteIcon__2"></span-->
# <span class="compare__icon spriteIcon__2 compareIcon"></span>
# </div>
# </div>
# <div class="highlight__cta__row">
# <div class="highlights__grid">
# <div class="highlight__div">
# <span class="highlight__name">Courses
#                                 Offered</span>
# <span class="highlight__value">
# <p title="Vellore Institute of Technology Courses &amp; Fee Details">4 Courses</p>
# </span>
# </div>
# <div class="highlight__div exam__accepted__div">
# <p class="highlight__name">Exam
#                                 Accepted</p>
# <span class="highlight__value">
# <span class="highlight__value"> -/- </span>
# </span></div>
# <div class="desktopOnly"></div>
# <div class="highlight__div">
# <span class="highlight__name">Tuition
#                                 Fees Range</span>
# <span class="highlight__value">
#                                 ₹5.25 L-14.25 L                            </span>
# </div>
# <div class="highlight__div">
# <span class="highlight__name">Accreditation</span>
# <span class="highlight__value">
# <span class="highlight__value"> -/- </span>
# <!--span class="highlight__value"> //!empty($model['median_salary']) ? '₹' . CollegeHelper::feesFormat(floor($model['median_salary'])) : '-/-' ?></span!-->
# </span></div>
# <div class="highlight__div"></div>
# </div>
# <div class="cta__grid">
# <div class="cta__div lead-cta-college-filter-2 leadFilterData download__brochure" data-cityid="678" data-course="" data-ctalocation="colleges_listing_vellore-institute-of-technology-vellore_card_right_cta_web" data-description="Vellore Institute of Technology, Vellore" data-entity="college" data-filter="college-listing" data-image="https://media.getmyuni.com/azure/college-image/small/vellore-institute-of-technology-vellore.jpg" data-lead_cta="21" data-slug="5445" data-stateid="15" data-stream="" data-title="Sign-up to Apply">
# </div>
# <div class="cta__div lead-cta-college-filter-1 leadFilterData primaryBtn" data-cityid="678" data-course="" data-ctalocation="colleges_listing_vellore-institute-of-technology-vellore_card_left_cta_web" data-description="Vellore Institute of Technology, Vellore" data-entity="college" data-filter="college-listing" data-image="https://media.getmyuni.com/azure/college-image/small/vellore-institute-of-technology-vellore.jpg" data-lead_cta="23" data-slug="5445" data-stateid="15" data-stream="" data-title="Sign-up to Download">
# </div>
# </div>
# </div>
# </div>
# <div class="college__card__new" id="search-175">
# <div class="card__header__row">
# <div class="college__detail__grid">
# <img alt="" class="college__image" height="56" loading="" onclick="gmu.url.goto('/college/bharathiar-university-bu-coimbatore')" src="https://media.getmyuni.com/azure/college-image/small/bharathiar-university-bu-coimbatore.jpg" width="56"/>
# <span class="list__style college__rank mobileOnly"> # 44 NIRF  </span>
# <div class="college__detail__row">
# <h2 class="college__name"><a data-hide="175" href="/college/bharathiar-university-bu-coimbatore" title="Bharathiar University">Bharathiar University</a></h2>
# <div class="detail__list__mobile">
# <span class="list__style college__location">Coimbatore, Tamil Nadu</span>
# <span class="list__style college__affiliation">Public</span>
# <a class="list__style list__style__rating" href="/college/bharathiar-university-bu-coimbatore/reviews" target="_blank" title="Bharathiar University, [BU] Coimbatore Reviews"><span class="list__style college__rating"><span class="spriteIcon__2 review__star__icon"></span>3.2</span> </a>
# <span class="list__style college__rank desktopOnly"> # 44 NIRF  </span> <div class="like__compare__grid mobileOnly">
# <!--span
#                                                                                                         class="heart__icon spriteIcon__2"></span-->
# <span class="compare__icon spriteIcon__2 compareIcon"></span>
# </div>
# </div>
# </div>
# </div>
# <div class="like__compare__grid desktopOnly">
# <!--span class="heart__icon spriteIcon__2"></span-->
# <span class="compare__icon spriteIcon__2 compareIcon"></span>
# </div>
# </div>
# <div class="highlight__cta__row">
# <div class="highlights__grid">
# <div class="highlight__div">
# <span class="highlight__name">Courses
#                                 Offered</span>
# <span class="highlight__value">
# <p> <a href=" https://www.getmyuni.com/college/bharathiar-university-bu-coimbatore-courses-fees" title="Bharathiar University Courses &amp; Fee Details">
#                                                 14 Courses
#                                             </a>
# </p>
# </span>
# </div>
# <div class="highlight__div exam__accepted__div">
# <p class="highlight__name">Exam
#                                 Accepted</p>
# <span class="highlight__value">
# <a href="/exams/csir-net" target="_blank">CSIR NET</a>
#                                                  ,                                                                                                 <a href="/exams/tancet" target="_blank">TANCET</a>
# </span>
# <div class="hover__tooltop"> <span class="hover__card">
# </span>
# </div>
# </div>
# <div class="desktopOnly"></div>
# <div class="highlight__div">
# <span class="highlight__name">Tuition
#                                 Fees Range</span>
# <span class="highlight__value">
#                                 ₹6 K-83 K                            </span>
# </div>
# <div class="highlight__div">
# <span class="highlight__name">Accreditation</span>
# <span class="highlight__value">
#                                                                                 NAAC-A
#                                         <div class="hover__tooltop"> <span class="hover__card">
# </span>
# </div>
# </span>
# <!--span class="highlight__value"> //!empty($model['median_salary']) ? '₹' . CollegeHelper::feesFormat(floor($model['median_salary'])) : '-/-' ?></span!-->
# </div>
# <div class="highlight__div"></div>
# </div>
# <div class="cta__grid">
# <div class="cta__div lead-cta-college-filter-2 leadFilterData download__brochure" data-cityid="628" data-course="" data-ctalocation="colleges_listing_bharathiar-university-bu-coimbatore_card_right_cta_web" data-description="Bharathiar University, Coimbatore" data-entity="college" data-filter="college-listing" data-image="https://media.getmyuni.com/azure/college-image/small/bharathiar-university-bu-coimbatore.jpg" data-lead_cta="21" data-slug="175" data-stateid="15" data-stream="" data-title="Sign-up to Apply">
# </div>
# <div class="cta__div lead-cta-college-filter-1 leadFilterData primaryBtn" data-cityid="628" data-course="" data-ctalocation="colleges_listing_bharathiar-university-bu-coimbatore_card_left_cta_web" data-description="Bharathiar University, Coimbatore" data-entity="college" data-filter="college-listing" data-image="https://media.getmyuni.com/azure/college-image/small/bharathiar-university-bu-coimbatore.jpg" data-lead_cta="23" data-slug="175" data-stateid="15" data-stream="" data-title="Sign-up to Download">
# </div>
# </div>
# </div>
# </div>
# <div class="sponser-list hide__widget">
# </div>
# <div class="cta__banner hide__widget">
# <p>Confused about which college or exam to opt for?</p>
# <p>Chat with our counselor Get your personalised list of
#                         colleges &amp; exams </p>
# <div class="cta__div primaryBtn brochureBtn leadFilterData predict-my-college-cta" data-cityid="628" data-course="" data-ctalocation="colleges_listing_single_top_cta_web" data-description="" data-entity="college" data-filter="college-listing" data-image="https://media.getmyuni.com/azure/college-image/small/bharathiar-university-bu-coimbatore.jpg" data-lead_cta="22" data-slug="175" data-stateid="15" data-stream="" data-title="Get Counselling from experts, free of cost !">
# </div>
# <img alt="banner image" src="../../yas/images/cta-banner.png"/>
# </div>
# <div class="searchedcollegeListGrid">
# <div class="college__card__new featured__card" id="search-549">
# <div class="card__header__row">
# <div class="college__detail__grid">
# <img alt="" class="college__image" height="56" loading="" onclick="gmu.url.goto('/college/hindustan-university-chennai')" src="https://media.getmyuni.com/azure/college-image/small/hindustan-university-chennai.jpg" width="56"/>
# <div class="college__detail__row">
# <h2 class="college__name"><a data-hide="549" href="/college/hindustan-university-chennai" title="Hindustan University">Hindustan University</a></h2>
# <div class="detail__list__mobile">
# <span class="list__style college__location">Chennai, Tamil Nadu</span>
# <span class="list__style college__affiliation">Private</span>
# <a class="list__style list__style__rating" href="/college/hindustan-university-chennai/reviews" target="_blank" title="Hindustan Institute of Technology and Science Reviews"><span class="list__style college__rating"><span class="spriteIcon__2 review__star__icon"></span>3.7</span> </a>
# <div class="like__compare__grid mobileOnly">
# <!--span
#                                                                                                         class="heart__icon spriteIcon__2"></span-->
# <span class="compare__icon spriteIcon__2 compareIcon"></span>
# </div>
# </div>
# </div>
# </div>
# <div class="like__compare__grid desktopOnly">
# <!--span class="heart__icon spriteIcon__2"></span-->
# <span class="compare__icon spriteIcon__2 compareIcon"></span>
# </div>
# </div>
# <div class="highlight__cta__row">
# <div class="highlights__grid">
# <div class="highlight__div">
# <span class="highlight__name">Courses
#                                                                                         Offered</span>
# <span class="highlight__value">
# <p> <a href=" https://www.getmyuni.com/college/hindustan-university-chennai-courses-fees" title="Hindustan University Courses &amp; Fee Details">
#                                                                                         24 Courses
#                                             </a>
# </p>
# </span>
# </div>
# <div class="highlight__div exam__accepted__div">
# <p class="highlight__name">Exam
#                                                                                         Accepted</p>
# <span class="highlight__value">
# <a href="/exams/cat" target="_blank">CAT</a>
#
#                                                                                                          ,                                                                                                                                                                                                 <a href="/exams/cmat" target="_blank">CMAT</a>
# </span>
# <div class="hover__tooltop">+7                                                                                                <span class="hover__card">
# <a href="/exams/hitscat" target="_blank">HITSCAT</a>,<a href="/exams/hitseee" target="_blank">HITSEEE</a>,<a href="/exams/jee-main" target="_blank">JEE Main</a>,<a href="/exams/mat" target="_blank">MAT</a>,<a href="/exams/nata" target="_blank">NATA</a>,<a href="/exams/tnea" target="_blank">TNEA</a>,<a href="/exams/xat" target="_blank">XAT</a>
# </span>
# </div>
# </div>
# <div class="desktopOnly"></div>
# <div class="highlight__div">
# <span class="highlight__name">Tuition
#                                                                                         Fees Range</span>
# <span class="highlight__value">
#                                                                                 ₹30 K-31.36 L                                                                                </span>
# </div>
# <div class="highlight__div">
# <span class="highlight__name">Accreditation</span>
# <span class="highlight__value">
#                                                                                                                                                                                 NAAC
#                                                                                         <div class="hover__tooltop"> <span class="hover__card">
# </span>
# </div>
# </span>
# <!--span class="highlight__value">//!empty($model['median_salary']) ? '₹' . CollegeHelper::feesFormat(floor($model['median_salary'])) : '-/-' ?></span!-->
# </div>
# <div class="highlight__div"></div>
# </div>
# <div class="cta__grid">
# <div class="cta__div lead-cta-college-filter-2 leadFilterData download__brochure" data-cityid="627" data-course="" data-ctalocation="colleges_listing_hindustan-university-chennai_card_right_cta_web" data-description="Hindustan University, Chennai" data-entity="college" data-filter="college-listing" data-image="https://media.getmyuni.com/azure/college-image/small/hindustan-university-chennai.jpg" data-lead_cta="21" data-slug="549" data-stateid="15" data-stream="" data-title="Sign-up to Apply"></div>
# <div class="cta__div lead-cta-college-filter-1 leadFilterData primaryBtn" data-cityid="627" data-course="" data-ctalocation="colleges_listing_hindustan-university-chennai_card_left_cta_web" data-description="Hindustan University, Chennai" data-entity="college" data-filter="college-listing" data-image="https://media.getmyuni.com/azure/college-image/small/hindustan-university-chennai.jpg" data-lead_cta="23" data-slug="549" data-stateid="15" data-stream="" data-title="Sign-up to Download"></div>
# </div>
# </div>
# </div>
# <div class="college__card__new featured__card" id="search-2699">
# <div class="card__header__row">
# <div class="college__detail__grid">
# <img alt="" class="college__image" height="56" loading="" onclick="gmu.url.goto('/college/easwari-engineering-college-eec-chennai')" src="https://media.getmyuni.com/azure/college-image/small/easwari-engineering-college-eec-chennai.jpg" width="56"/>
# <div class="college__detail__row">
# <h2 class="college__name"><a data-hide="2699" href="/college/easwari-engineering-college-eec-chennai" title="Easwari Engineering College">Easwari Engineering College</a></h2>
# <div class="detail__list__mobile">
# <span class="list__style college__location">Chennai, Tamil Nadu</span>
# <span class="list__style college__affiliation">Private</span>
# <a class="list__style list__style__rating" href="/college/easwari-engineering-college-eec-chennai/reviews" target="_blank" title="SRM Easwari Engineering College, Chennai Reviews"><span class="list__style college__rating"><span class="spriteIcon__2 review__star__icon"></span>3.2</span> </a>
# <div class="like__compare__grid mobileOnly">
# <!--span
#                                                                                                         class="heart__icon spriteIcon__2"></span-->
# <span class="compare__icon spriteIcon__2 compareIcon"></span>
# </div>
# </div>
# </div>
# ...
# <p class="feedback-text">Thanks for FeedBack </p>
# </div>
# </form>
# </div>
# <!-- scroll to top -->
# <img class="scrollToTop" loading="lazy" src="/yas/images/scroll_to_top.webp"/>
# <style>
#     /* .whatsappIntegrationIcon {
#         position: fixed;
#         bottom: 130px;
#         right: 17px;
#         z-index: 10;
#         width: 60px;
#         height: 60px;
#         transform: translateY(50px);
#     }
#
#     @media (max-width: 1023px) {
#         .whatsappIntegrationIcon {
#             bottom: 118px;
#             right: 19px;
#         }
#     } */
#
#     .whatsappIntegrationIcon {
#         background-color: #29d74c;
#         width: 60px;
#         height: 60px;
#         padding: 5px;
#         justify-content: center;
#         display: flex;
#         align-items: center;
#         flex-direction: column;
#         border-radius: 50%;
#         cursor: pointer;
#         position: fixed;
#         bottom: 69px;
#         right: 30px;
#         z-index: 10;
#         animation-name: pulse;
#         animation-duration: 1.5s;
#         animation-timing-function: ease-out;
#         animation-iteration-count: infinite;
#     }
#
#     @keyframes pulse {
#         0% {
#             -webkit-transform: scale(1);
#             -ms-transform: scale(1);
#             transform: scale(1);
#         }
#
#         50% {
#             -webkit-transform: scale(1.1);
#             -ms-transform: scale(1.1);
#             transform: scale(1.1);
#         }
#
#         100% {
#             -webkit-transform: scale(1);
#             -ms-transform: scale(1);
#             transform: scale(1);
#         }
#     }
#
#     .whatsappIntegrationIcon img {
#         width: 30px;
#         height: 30px;
#         color: transparent;
#
#     }
#
#     @media (max-width: 1023px) {
#         .whatsappIntegrationIcon {
#             right: 20px;
#         }
#     }
# </style>
# <a class="whatsappIntegrationIcon" href="https://api.whatsapp.com/send?phone=+919910525319&amp;text= Hi! I am looking for colleges to take admission in 2024. Can you help connect me to a college expert?" rel="nofollow" target="_blank">
# <img id="shareWp" src="/yas/images/WhatsApp.webp"/>
# </a> <!--div class="extended__footer">
#                 <section class="extended__footer__section">
#                         <h4 class="accordian__label">MBA</h4>
#                         <ul class="accordian__expand">
#                                 <li>MBA</li>
#                                 <li>Top MBA Colleges</li>
#                                 <li>Executive MBA Colleges</li>
#                                 <li>CAT</li>
#                                 <li>MAT</li>
#                         </ul>
#                 </section>
#                 <section class="extended__footer__section">
#                         <h4 class="accordian__label">Engineering</h4>
#                         <ul class="accordian__expand">
#                                 <li>Engineering</li>
#                                 <li>Top Engineering Colleges</li>
#                                 <li>Executive Engineering Colleges</li>
#                                 <li>JEE MAINS</li>
#                                 <li>ADVANCe</li>
#                         </ul>
#                 </section>
#                 <section class="extended__footer__section">
#                         <h4 class="accordian__label">Medicine</h4>
#                         <ul class="accordian__expand">
#                                 <li>Engineering</li>
#                                 <li>Top Engineering Colleges</li>
#                                 <li>Executive Engineering Colleges</li>
#                                 <li>JEE MAINS</li>
#                                 <li>ADVANCe</li>
#                                 <li>Engineering</li>
#                                 <li>Top Engineering Colleges</li>
#                                 <li>Executive Engineering Colleges</li>
#                                 <li>JEE MAINS</li>
#                                 <li>ADVANCe</li>
#                         </ul>
#                 </section>
#                 <section class="extended__footer__section">
#                         <h4 class="accordian__label">Others</h4>
#                         <ul class="accordian__expand">
#                                 <li>Animation</li>
#                                 <li>Top B,Sc Colleges</li>
#                                 <li>Executive Engineering Colleges</li>
#                                 <li>Mass</li>
#                                 <li>Law</li>
#                                 <li>Design</li>
#                                 <li>ABC Colleges</li>
#                                 <li>Executive Engineering Colleges</li>
#                                 <li>JEE MAINS</li>
#                                 <li>ADVANCe</li>
#                         </ul>
#                 </section>
#                 <section class="extended__footer__section">
#                         <h4 class="accordian__label">Others</h4>
#                         <ul class="accordian__expand">
#                                 <li>Animation</li>
#                                 <li>Top B,Sc Colleges</li>
#                                 <li>Executive Engineering Colleges</li>
#                                 <li>Mass</li>
#                                 <li>Law</li>
#                                 <li>Design</li>
#                                 <li>ABC Colleges</li>
#                                 <li>Executive Engineering Colleges</li>
#                                 <li>JEE MAINS</li>
#                                 <li>ADVANCe</li>
#                         </ul>
#                 </section>
#                 <section class="extended__footer__section">
#                         <h4 class="accordian__label">Others</h4>
#                         <ul class="accordian__expand">
#                                 <li>Animation</li>
#                                 <li>Top B,Sc Colleges</li>
#                                 <li>Executive Engineering Colleges</li>
#                                 <li>Mass</li>
#                                 <li>Law</li>
#                                 <li>Design</li>
#                                 <li>ABC Colleges</li>
#                                 <li>Executive Engineering Colleges</li>
#                                 <li>JEE MAINS</li>
#                                 <li>ADVANCe</li>
#                         </ul>
#                 </section>
#                 <section class="extended__footer__section">
#                         <h4 class="accordian__label">Others</h4>
#                         <ul class="accordian__expand">
#                                 <li>Animation</li>
#                                 <li>Top B,Sc Colleges</li>
#                                 <li>Executive Engineering Colleges</li>
#                                 <li>Mass</li>
#                                 <li>Law</li>
#                                 <li>Design</li>
#                                 <li>ABC Colleges</li>
#                                 <li>Executive Engineering Colleges</li>
#                                 <li>JEE MAINS</li>
#                                 <li>ADVANCe</li>
#                         </ul>
#                 </section>
#                 <section class="extended__footer__section">
#                         <h4 class="accordian__label">Others</h4>
#                         <ul class="accordian__expand">
#                                 <li>Animation</li>
#                                 <li>Top B,Sc Colleges</li>
#                                 <li>Executive Engineering Colleges</li>
#                                 <li>Mass</li>
#                                 <li>Law</li>
#                                 <li>Design</li>
#                                 <li>ABC Colleges</li>
#                                 <li>Executive Engineering Colleges</li>
#                                 <li>JEE MAINS</li>
#                                 <li>ADVANCe</li>
#                         </ul>
#                 </section>
#
#         </div-->
# <footer class="pageFooter">
# <div class="footerPrimarySection">
# <div class="container">
# <div class="row">
# <img alt="Getmyuni Logo" class="lazyload" data-src="https://media.getmyuni.com/yas/images/gmulogo.png" height="40" loading="lazy" src="https://media.getmyuni.com/yas/images/gmulogo.png" width="172"/>
# <div>
# <ul class="socialMedia">
# <li>Connect with us</li>
# <li><a class="spriteIcon fbIcon" href="https://www.facebook.com/getmyuniedu" rel="noopener nofollow" target="_blank" title="Facebook"></a></li>
# <li><a class="spriteIcon twitterIcon" href="https://twitter.com/getmyuniedu" rel="noopener nofollow" target="_blank" title="Twitter"></a></li>
# <li><a class="spriteIcon instaIcon" href="https://www.instagram.com/getmyuni/" rel="noopener nofollow" target="_blank" title="Instagram"></a>
# </li>
# <li><a class="spriteIcon linkdIn" href="https://www.linkedin.com/company/getmyuni" rel="noopener nofollow" target="_blank" title="Linkedin"></a></li>
# <li><a class="spriteIcon youtubeIcon" href="https://www.youtube.com/channel/UCvczFiMv9OZwYkFydoNdMCA" rel="noopener nofollow" target="_blank" title="Youtube"></a>
# </li>
# </ul>
# <ul class="contactInfo">
# <li><span class="spriteIcon phoneIcon"></span><a href="tel:+918884099411" title="+918884099411">+91 8884099411</a>
# </li>
# <li><span class="spriteIcon whiteMailIcon"></span> <a href="mailTo:contact@getmyuni.com" title="contact@getmyuni.com">contact@getmyuni.com</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="footerSecondSection">
# <div class="container">
# <div class="row">
# <ul>
# <li><a href="https://www.getmyuni.com/about-us" title="About Us">About Us</a></li>
# <li><a href="https://www.getmyuni.com/contact-us" title="Contact Us">Contact Us</a></li>
# <li><a href="https://www.getmyuni.com/privacy-policy" title="Privacy Policy">Privacy Policy</a></li>
# <li><a href="https://www.getmyuni.com/terms-and-conditions" title="Terms &amp; Conditions">Terms &amp; Conditions</a></li>
# </ul>
# <p class="copyrightsText">
#                     © 2024 Getmyuni.com. All Rights Reserved.                </p>
# </div>
# </div>
# </div>
# </footer>
# <script src="/yas/js/version2/ajax/libs/js/jquery.min.js?v=1707645615"></script>
# <script src="/yas/assets/99c91b8d/yii.js?v=1677236426"></script>
# <script defer="" src="/yas/js/version2/ajax/libs/js/select2.min.js?v=1707645615"></script>
# <script src="/yas/js/version2/ajax/libs/js/jquery-ui.min.js?v=1707645615"></script>
# <script src="/yas/js/version2/ajax/libs/js/slick.min.js?v=1707645615"></script>
# <script src="/yas/js/version2/min/college-filter-page.js?v=1729774232"></script>
# <script defer="" src="/yas/js/version2/min/global.js?v=1729774232"></script>
# <script defer="" src="/yas/js/version2/min/script.js?v=1729774232"></script>
# <script defer="" src="/yas/js/version2/min/filter_script.js?v=1729774232"></script>
# <script defer="" src="/yas/js/version2/min/login.js?v=1729774232"></script> <div id="lead-form-js-new" style="display: none"></div>
# <div id="login-form-js" style="display: none"></div>
# <div id="fees-breakup" style="display: none;"></div>
# <!-- <div id="banner-popup"></div> -->
# <!-- Loading Icon -->
# <div class="pageLoader" id="filter-loader">
# <div class="pageLoaderDiv">
# <div class="circle"></div>
# <p class="loadText">Loading...</p>
# </div>
# </div>
# <script>
#         function hideAdSection(e) {
#             var n = e.slot.getSlotElementId();
#             if ("" != n || "undefined" != n) {
#                 var d = "",
#                     t = "",
#                     l = "";
#                 if (d = document.getElementById(n).parentNode, (null != d || "undefined" != d || "" != d)) {
#                     d.style.display = "none";
#                 }
#             }
#         }
#         window.addEventListener('load', function() {
#             setTimeout(() => {
#                 const script = document.createElement('script');
#                 script.src = 'https://securepubads.g.doubleclick.net/tag/js/gpt.js';
#                 document.getElementsByTagName('head')[0].appendChild(script);
#                 $('.lazy-ad').each(function() {
#                     var refreshed = false;
#                     var threshold = 640;
#                     var element = $(this);
#                     var scrollId = element.data('slot');
#                     if (element.offset().top < threshold) {
#                         if (!refreshed) {
#                             googletag.cmd.push(function() {
#                                 googletag.pubads().refresh([gptAdSlots[scrollId]]);
#                             });
#                             refreshed = true;
#                         }
#                     } else {
#                         var listener = function() {
#                             var adSlotPos = element.offset().top;
#                             var adAlmostVisibleScrollValue = adSlotPos - 700;
#                             if (window.scrollY >= adAlmostVisibleScrollValue && !refreshed) {
#                                 googletag.cmd.push(function() {
#                                     googletag.pubads().refresh([gptAdSlots[scrollId]]);
#                                 });
#                                 refreshed = true;
#                                 window.removeEventListener('scroll', listener);
#                             }
#                         }
#                         window.addEventListener('scroll', listener);
#                     }
#                 })
#             }, 7000);
#         });
#     </script>
# <script>
#         (function() {
#             var base_url = window.location.origin;
#             var cssAutoComplete = document.createElement('link');
#             // cssAutoComplete.href = 'https://cdnjs.cloudflare.com/ajax/libs/tarekraafat-autocomplete.js/8.3.0/css/autoComplete.min.css';
#             cssAutoComplete.href = base_url + '/yas/css/version2/ajax/libs/css/autoComplete.min.css';
#             cssAutoComplete.rel = 'stylesheet';
#             cssAutoComplete.type = 'text/css';
#             document.getElementsByTagName('head')[0].appendChild(cssAutoComplete);
#
#             var cssSelect2 = document.createElement('link');
#             // cssSelect2.href = 'https://cdnjs.cloudflare.com/ajax/libs/select2/4.1.0-rc.0/css/select2.min.css';
#             cssSelect2.href = base_url + '/yas/css/version2/ajax/libs/css/select2.min.css';
#             cssSelect2.rel = 'stylesheet';
#             cssSelect2.type = 'text/css';
#             document.getElementsByTagName('head')[0].appendChild(cssSelect2);
#
#             var cssSlick = document.createElement('link');
#             // cssSlick.href = 'https://cdnjs.cloudflare.com/ajax/libs/slick-carousel/1.8.1/slick.min.css';
#             cssSlick.href = base_url + '/yas/css/version2/ajax/libs/css/slick.min.css';
#             cssSlick.rel = 'stylesheet';
#             cssSlick.type = 'text/css';
#             document.getElementsByTagName('head')[0].appendChild(cssSlick);
#
#             var jsAutoComplete = document.createElement('script');
#             // jsAutoComplete.src = "https://cdnjs.cloudflare.com/ajax/libs/tarekraafat-autocomplete.js/8.3.0/js/autoComplete.min.js";
#             jsAutoComplete.src = base_url + "/yas/js/version2/ajax/libs/js/autoComplete.min.js";
#             var script = document.getElementsByTagName('script')[0];
#             script.defer = true;
#             script.parentNode.insertBefore(jsAutoComplete, script);
#
#         })();
#
#         if ('loading' in HTMLImageElement.prototype) {
#             const images = document.querySelectorAll('img[loading="lazy"]');
#             images.forEach(img => {
#                 img.src = img.dataset.src ?? img.src;
#             });
#         } else {
#             var base_url = window.location.origin;
#             // Dynamically import the LazySizes library
#             const script = document.createElement('script');
#             // script.src ='https://cdnjs.cloudflare.com/ajax/libs/lazysizes/5.1.2/lazysizes.min.js';
#             script.src = base_url + '/yas/js/version2/ajax/libs/js/lazysizes.min.js';
#             script.defer = true;
#             document.body.appendChild(script);
#         }
#     </script>
#
# </html>

# %%
names=soup.find_all('h2',class_='college__name')
city=soup.find_all('div',class_='detail__list__mobile')
fees=soup.find_all('span',class_='highlight__value')

# %%
college_names = []
college_cities = []
college_fees = []

# %%
for name, city, fee in zip(names, city, fees):
    college_names.append(name.text.strip())
    college_cities.append(city.text.strip())
    college_fees.append(fee.text.strip())

# %%
college_data = {'college_names':college_names, 'college_cities':college_cities, 'college_fees':college_fees}
print(college_data)
# Out:
# {'college_names': ['IIT Madras', 'Amrita Vishwa Vidyapeetham', 'Vellore Institute of Technology', 'Bharathiar University', 'Hindustan University', 'Easwari Engineering College', 'NIT Trichy', 'Anna University', 'SASTRA University', 'Madras University', 'SRM Institute of Science and Technology, Trichy', 'SRM TRP Engineering College', 'Saveetha University', 'SRM University (SRM IST)', 'Alagappa University', 'Sathyabama University', 'Presidency University', 'Vignan Online', 'Kalasalingam University', 'Bharath University', 'Sri Ramachandra University / Sri Ramachandra Medical College and Research Institute, Chennai', 'Madurai Kamaraj University (MKU)', 'SNU', 'PSGCT', 'Sri Sivasubramaniya Nadar College of Engineering, Chennai', 'Bharathidasan University', 'VIT Vellore', 'Loyola College', 'Madras Christian College', 'Bannari Amman Institute of Technology', 'Kongu Engineering College', 'Karunya University', 'CEG Guindy'], 'college_cities': ['Chennai, Tamil Nadu\nPublic\n4.3 \n # 1 NIRF', 'Coimbatore, Tamil Nadu\nPrivate\n3.9 \n # 18 NIRF', 'Vellore, Tamil Nadu\n\n4.2', 'Coimbatore, Tamil Nadu\nPublic\n3.2 \n # 44 NIRF', 'Chennai, Tamil Nadu\nPrivate\n3.7', 'Chennai, Tamil Nadu\nPrivate\n3.2', 'Tiruchirappalli, Tamil Nadu\nPublic\n3.4 \n # 31 NIRF', 'Chennai, Tamil Nadu\nPublic\n3.2 \n # 20 NIRF', 'Thanjavur, Tamil Nadu\nPrivate\n3.8 \n # 47 NIRF', 'Chennai, Tamil Nadu\nPublic\n3.5 \n # 64 NIRF', 'Trichy, Tamil Nadu', 'Trichy, Tamil Nadu\nPrivate\n2.6', 'Chennai, Tamil Nadu\nPrivate\n4.3', 'Chennai, Tamil Nadu\nPrivate\n3.8 \n # 21 NIRF', 'Karaikudi, Tamil Nadu\nPublic\n4.1 \n # 76 NIRF', 'Chennai, Tamil Nadu\nPrivate\n3.5', 'Bangalore, Karnataka\nPrivate\n3.9', 'Guntur, Andhra Pradesh', 'Krishnakoil, Tamil Nadu\nPrivate\n2.6 \n # 50 NIRF', 'Chennai, Tamil Nadu\nPrivate\n3.2 \n # 91 NIRF', 'Chennai, Tamil Nadu\nPrivate\n4.3 \n # 96 NIRF', 'Madurai, Tamil Nadu\nPublic\n3.5', 'Chennai, Tamil Nadu\nPrivate', 'Coimbatore, Tamil Nadu\nPrivate\n3.7', 'Chennai, Tamil Nadu\nPrivate\n3.4 \n # 81 NIRF', 'Tiruchirappalli, Tamil Nadu\nPublic\n3.3 \n # 55 NIRF', 'Vellore, Tamil Nadu\nPrivate\n3.8 \n # 19 NIRF', 'Chennai, Tamil Nadu\nPrivate\n3.7', 'Chennai, Tamil Nadu\nPrivate\n3.2', 'Coimbatore, Tamil Nadu\nPrivate\n4.1', 'Erode, Tamil Nadu\nPrivate\n4.0', 'Coimbatore, Tamil Nadu\nDeemed University/Private\n3.4', 'Chennai, Tamil Nadu\nPublic\n3.2'], 'college_fees': ['7 Courses', 'CAT\n                                                 ,                                                                                                 IIT JAM', '₹6 K-8 L', '-/-', '-/-', '10 Courses', 'CAT', '₹90 K-16.33 L', '-/-', '-/-', '4 Courses', '-/-', '-/-', '₹5.25 L-14.25 L', '-/-', '-/-', '14 Courses', 'CSIR NET\n                                                 ,                                                                                                 TANCET', '₹6 K-83 K', 'NAAC-A', '24 Courses', 'CAT\n\n                                                                                                         ,                                                                                                                                                                                                 CMAT', '₹30 K-31.36 L', 'NAAC', '5 Courses', 'TANCET', '₹82 K-3.48 L', 'NBA', '8 Courses', 'CAT\n                                                 ,                                                                                                 GATE', '₹30 K-6.25 L', 'NIRF', '13 Courses']}

# %%
model=pd.DataFrame(data=college_data)
model.to_csv("colleges_tamilnadu_data.csv")
model
# Out:
#                                         college_names  \
# 0                                          IIT Madras
# 1                          Amrita Vishwa Vidyapeetham
# 2                     Vellore Institute of Technology
# 3                               Bharathiar University
# 4                                Hindustan University
# 5                         Easwari Engineering College
# 6                                          NIT Trichy
# 7                                     Anna University
# 8                                   SASTRA University
# 9                                   Madras University
# 10    SRM Institute of Science and Technology, Trichy
# 11                        SRM TRP Engineering College
# 12                                Saveetha University
# 13                           SRM University (SRM IST)
# 14                                Alagappa University
# 15                              Sathyabama University
# 16                              Presidency University
# 17                                      Vignan Online
# 18                            Kalasalingam University
# 19                                 Bharath University
# 20  Sri Ramachandra University / Sri Ramachandra M...
# 21                   Madurai Kamaraj University (MKU)
# 22                                                SNU
# 23                                              PSGCT
# 24  Sri Sivasubramaniya Nadar College of Engineeri...
# 25                           Bharathidasan University
# 26                                        VIT Vellore
# 27                                     Loyola College
# 28                           Madras Christian College
# 29              Bannari Amman Institute of Technology
# 30                          Kongu Engineering College
# 31                                 Karunya University
# 32                                         CEG Guindy
#
#                                        college_cities  \
# 0        Chennai, Tamil Nadu\nPublic\n4.3 \n # 1 NIRF
# 1   Coimbatore, Tamil Nadu\nPrivate\n3.9 \n # 18 NIRF
# 2                          Vellore, Tamil Nadu\n\n4.2
# 3    Coimbatore, Tamil Nadu\nPublic\n3.2 \n # 44 NIRF
# 4                   Chennai, Tamil Nadu\nPrivate\n3.7
# 5                   Chennai, Tamil Nadu\nPrivate\n3.2
# 6   Tiruchirappalli, Tamil Nadu\nPublic\n3.4 \n # ...
# 7       Chennai, Tamil Nadu\nPublic\n3.2 \n # 20 NIRF
# 8    Thanjavur, Tamil Nadu\nPrivate\n3.8 \n # 47 NIRF
# 9       Chennai, Tamil Nadu\nPublic\n3.5 \n # 64 NIRF
# 10                                 Trichy, Tamil Nadu
# 11                   Trichy, Tamil Nadu\nPrivate\n2.6
# 12                  Chennai, Tamil Nadu\nPrivate\n4.3
# 13     Chennai, Tamil Nadu\nPrivate\n3.8 \n # 21 NIRF
# 14    Karaikudi, Tamil Nadu\nPublic\n4.1 \n # 76 NIRF
# 15                  Chennai, Tamil Nadu\nPrivate\n3.5
# 16                 Bangalore, Karnataka\nPrivate\n3.9
# 17                             Guntur, Andhra Pradesh
# 18  Krishnakoil, Tamil Nadu\nPrivate\n2.6 \n # 50 ...
# 19     Chennai, Tamil Nadu\nPrivate\n3.2 \n # 91 NIRF
# 20     Chennai, Tamil Nadu\nPrivate\n4.3 \n # 96 NIRF
# 21                   Madurai, Tamil Nadu\nPublic\n3.5
# 22                       Chennai, Tamil Nadu\nPrivate
# 23               Coimbatore, Tamil Nadu\nPrivate\n3.7
# 24     Chennai, Tamil Nadu\nPrivate\n3.4 \n # 81 NIRF
# 25  Tiruchirappalli, Tamil Nadu\nPublic\n3.3 \n # ...
# 26     Vellore, Tamil Nadu\nPrivate\n3.8 \n # 19 NIRF
# 27                  Chennai, Tamil Nadu\nPrivate\n3.7
# 28                  Chennai, Tamil Nadu\nPrivate\n3.2
# 29               Coimbatore, Tamil Nadu\nPrivate\n4.1
# 30                    Erode, Tamil Nadu\nPrivate\n4.0
# 31  Coimbatore, Tamil Nadu\nDeemed University/Priv...
# 32                   Chennai, Tamil Nadu\nPublic\n3.2
#
#                                          college_fees
# 0                                           7 Courses
# 1   CAT\n                                         ...
# 2                                            ₹6 K-8 L
# 3                                                 -/-
# 4                                                 -/-
# 5                                          10 Courses
# 6                                                 CAT
# 7                                       ₹90 K-16.33 L
# 8                                                 -/-
# 9                                                 -/-
# 10                                          4 Courses
# 11                                                -/-
# 12                                                -/-
# 13                                    ₹5.25 L-14.25 L
# 14                                                -/-
# 15                                                -/-
# 16                                         14 Courses
# 17  CSIR NET\n                                    ...
# 18                                          ₹6 K-83 K
# 19                                             NAAC-A
# 20                                         24 Courses
# 21  CAT\n\n                                       ...
# 22                                      ₹30 K-31.36 L
# 23                                               NAAC
# 24                                          5 Courses
# 25                                             TANCET
# 26                                       ₹82 K-3.48 L
# 27                                                NBA
# 28                                          8 Courses
# 29  CAT\n                                         ...
# 30                                       ₹30 K-6.25 L
# 31                                               NIRF
# 32                                         13 Courses
